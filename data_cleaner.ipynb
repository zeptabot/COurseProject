# %% [markdown]
# # Data cleaner + Variable Searcher
# ### Add to the beginning of your notebook
# **Imports the data and does the recommended cleaning. Adds 3 functions modified from variable searcher to return detailed information about variables.**
# Variable names:
# - cols: the list of variables
# - data: the original dataframe
#
# Functions:
# - get_matching_keywords: takes a list of strings and returns all variables who contain at least one keyword
# - get_var_details: takes a variable name and returns a list of questions corresponding to which dataset the variable is from
# - get_column_info: takes a variable name and returns a list of every question associated with the variable as well as information about the type and amount of responses to the question.

# %%
import pandas as pd
cols = pd.read_csv("var_names.csv")
data = pd.read_csv('CSCS_data_anon.csv', low_memory=False,
                        na_values=["9999", "", " ", "Presented but no response", "NA"])
empty = (data.isna().sum()==data.shape[0])
data = data[empty.index[~empty]] # keep non empty columns only
data = data[data.REMOVE_case=='No'].copy()

# %%
def get_matching_keywords(keywords: list[str]) -> list[str]:
    """
    Returns the names of the columns whose string contains any of the keywords
    """
    global data
    return [col for col in data.columns if any(keyword.lower() in col.lower() for keyword in keywords)]

def get_var_details(var_name: str) -> list[tuple[str, str]]:
    """
    Returns a list of pairs detailing the question and datasets 
    corresponding to the given variable name
    """
    global cols
    filtered_data = cols[cols['new_var'] == var_name]
    
    info = []
    result: pd.DataFrame = filtered_data[['new_var', 'text', 'dataset']]
    for index, row in result.iterrows():
        info.append((row['text'], row['dataset']))

    return info

def get_column_info(column_name: str) -> None:
    """
    Returns information about a given column
    """
    global data, cols
    column_info: pd.DataFrame = data[column_name]
    print(f"{' Information about: ' + column_name + ' ':-^70}")
    details = get_var_details(column_name)
    if not details: print(f"{' No associated question found ':-^70}")
    for question, dataset in details:
        print(f"{' Dataset: ' + dataset + ' ':-^70}")
        print(f"{' Question: ' + question + ' ':-^70}")
        print(f"{'':-^70}\n")
    print(f"Number of NA: {column_info.isna().sum()}")
    print(column_info.value_counts())
    print("")

# %%
# Example usage
words = ["lonely"]
to_examine = get_matching_keywords(words)
for col in to_examine:
    get_column_info(col)
# Out:
# --- Information about: LONELY_ucla_loneliness_scale_companionship ----
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: Indicate how often each of the statements below is descriptive of you. - How often do you feel that you lack companionship?
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: Indicate how often each of the statements below is descriptive of you. - How often do you feel that you lack companionship?
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Indicate how often each of the statements below is descriptive of you. - How often do you feel that you lack companionship?
# ----------------------------------------------------------------------
#
# Number of NA: 6764
# LONELY_ucla_loneliness_scale_companionship
# Some of the time    1650
# Hardly Ever         1017
# Often                587
# Name: count, dtype: int64
#
# ------ Information about: LONELY_ucla_loneliness_scale_left_out ------
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: Indicate how often each of the statements below is descriptive of you. - How often do you feel left out?
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: Indicate how often each of the statements below is descriptive of you. - How often do you feel left out?
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Indicate how often each of the statements below is descriptive of you. - How often do you feel left out?
# ----------------------------------------------------------------------
#
# Number of NA: 6769
# LONELY_ucla_loneliness_scale_left_out
# Some of the time    1412
# Hardly Ever         1222
# Often                615
# Name: count, dtype: int64
#
# ------ Information about: LONELY_ucla_loneliness_scale_isolated ------
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: Indicate how often each of the statements below is descriptive of you. - How often do you feel isolated from others?
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: Indicate how often each of the statements below is descriptive of you. - How often do you feel isolated from others?
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Indicate how often each of the statements below is descriptive of you. - How often do you feel isolated from others?
# ----------------------------------------------------------------------
#
# Number of NA: 6774
# LONELY_ucla_loneliness_scale_isolated
# Some of the time    1523
# Hardly Ever          973
# Often                748
# Name: count, dtype: int64
#
#  Information about: LONELY_dejong_emotional_social_loneliness_scale_emptiness
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: Please indicate for each of the statements, the extent to which they apply to your situation, the way you feel now. - I experience a general sense of emptiness
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: Please indicate for each of the statements, the extent to which they apply to your situation, the way you feel now. - I experience a general sense of emptiness
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: For the statements below, please indicate the extent to which they apply to your situation and the way you feel now. - I experience a general sense of emptiness
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Please indicate for each of the statements, the extent to which they apply to your situation, the way you feel now. - I experience a general sense of emptiness
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cross -------------------------
#  Question: For the statements below, please indicate the extent to which they apply to your situation and the way you feel now. - I experience a general sense of emptiness
# ----------------------------------------------------------------------
#
# Number of NA: 2281
# LONELY_dejong_emotional_social_loneliness_scale_emptiness
# No              3040
# More or less    2592
# Yes             2105
# Name: count, dtype: int64
#
#  Information about: LONELY_dejong_emotional_social_loneliness_scale_rely
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: Please indicate for each of the statements, the extent to which they apply to your situation, the way you feel now. - There are plenty of people I can rely on when I have problems
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: Please indicate for each of the statements, the extent to which they apply to your situation, the way you feel now. - There are plenty of people I can rely on when I have problems
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: For the statements below, please indicate the extent to which they apply to your situation and the way you feel now. - There are plenty of people I can rely on when I have problems
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Please indicate for each of the statements, the extent to which they apply to your situation, the way you feel now. - There are plenty of people I can rely on when I have problems
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cross -------------------------
#  Question: For the statements below, please indicate the extent to which they apply to your situation and the way you feel now. - There are plenty of people I can rely on when I have problems
# ----------------------------------------------------------------------
#
# Number of NA: 2250
# LONELY_dejong_emotional_social_loneliness_scale_rely
# More or less    3048
# Yes             2812
# No              1908
# Name: count, dtype: int64
#
#  Information about: LONELY_dejong_emotional_social_loneliness_scale_trust
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: Please indicate for each of the statements, the extent to which they apply to your situation, the way you feel now. - There are many people I can trust completely
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: Please indicate for each of the statements, the extent to which they apply to your situation, the way you feel now. - There are many people I can trust completely
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: For the statements below, please indicate the extent to which they apply to your situation and the way you feel now. - There are many people I can trust completely
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Please indicate for each of the statements, the extent to which they apply to your situation, the way you feel now. - There are many people I can trust completely
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cross -------------------------
#  Question: For the statements below, please indicate the extent to which they apply to your situation and the way you feel now. - There are many people I can trust completely
# ----------------------------------------------------------------------
#
# Number of NA: 2270
# LONELY_dejong_emotional_social_loneliness_scale_trust
# More or less    2766
# Yes             2525
# No              2457
# Name: count, dtype: int64
#
#  Information about: LONELY_dejong_emotional_social_loneliness_scale_close
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: Please indicate for each of the statements, the extent to which they apply to your situation, the way you feel now. - There are enough people I feel close to
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: Please indicate for each of the statements, the extent to which they apply to your situation, the way you feel now. - There are enough people I feel close to
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: For the statements below, please indicate the extent to which they apply to your situation and the way you feel now. - There are enough people I feel close to
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Please indicate for each of the statements, the extent to which they apply to your situation, the way you feel now. - There are enough people I feel close to
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cross -------------------------
#  Question: For the statements below, please indicate the extent to which they apply to your situation and the way you feel now. - There are enough people I feel close to
# ----------------------------------------------------------------------
#
# Number of NA: 2269
# LONELY_dejong_emotional_social_loneliness_scale_close
# Yes             3177
# More or less    2713
# No              1859
# Name: count, dtype: int64
#
#  Information about: LONELY_dejong_emotional_social_loneliness_scale_miss
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: Please indicate for each of the statements, the extent to which they apply to your situation, the way you feel now. - I miss having people around
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: Please indicate for each of the statements, the extent to which they apply to your situation, the way you feel now. - I miss having people around
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: For the statements below, please indicate the extent to which they apply to your situation and the way you feel now. - I miss having people around
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Please indicate for each of the statements, the extent to which they apply to your situation, the way you feel now. - I miss having people around
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cross -------------------------
#  Question: For the statements below, please indicate the extent to which they apply to your situation and the way you feel now. - I miss having people around
# ----------------------------------------------------------------------
#
# Number of NA: 2290
# LONELY_dejong_emotional_social_loneliness_scale_miss
# Yes             3346
# More or less    2525
# No              1857
# Name: count, dtype: int64
#
#  Information about: LONELY_dejong_emotional_social_loneliness_scale_rejected
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: Please indicate for each of the statements, the extent to which they apply to your situation, the way you feel now. - I often feel rejected
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: Please indicate for each of the statements, the extent to which they apply to your situation, the way you feel now. - I often feel rejected
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: For the statements below, please indicate the extent to which they apply to your situation and the way you feel now. - I often feel rejected
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Please indicate for each of the statements, the extent to which they apply to your situation, the way you feel now. - I often feel rejected
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cross -------------------------
#  Question: For the statements below, please indicate the extent to which they apply to your situation and the way you feel now. - I often feel rejected
# ----------------------------------------------------------------------
#
# Number of NA: 2293
# LONELY_dejong_emotional_social_loneliness_scale_rejected
# No              3726
# More or less    2307
# Yes             1692
# Name: count, dtype: int64
#
# ------------------ Information about: LONELY_direct ------------------
# ------------------------ Dataset: 2021_cross -------------------------
# ------- Question: During the PAST WEEK, have you felt lonely  --------
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
# ------- Question: During the PAST WEEK, have you felt lonely  --------
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cross -------------------------
# ------- Question: During the PAST WEEK, have you felt lonely  --------
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
# ------- Question: During the PAST WEEK, have you felt lonely  --------
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cross -------------------------
# ------- Question: During the PAST WEEK, have you felt lonely  --------
# ----------------------------------------------------------------------
#
# Number of NA: 2235
# LONELY_direct
# Rarely (e.g. less than 1 day)                                2134
# Some or a little of the time (e.g. 1-2 days)                 2069
# None of the time (e.g., 0 days)                              1481
# Occasionally or a moderate amount of time (e.g. 3-4 days)    1419
# All of the time (e.g. 5-7 days)]                              680
# Name: count, dtype: int64
#
# ----------------- Information about: LONELY_duration -----------------
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: For about how long have you consistently felt that you were lonely [QID45-ChoiceGroup-SelectedChoices]?
# ----------------------------------------------------------------------
#
# Number of NA: 7408
# LONELY_duration
# The past 6 months     872
# 6 months to a year    645
# 1 to 2 years          518
# 3 to 5 years          251
# More than 10 years    232
# 6 to 10 years          92
# Name: count, dtype: int64
#
# ------------- Information about: LONELY_change_pre_covid -------------
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: Comparing how you feel now to how you felt before the COVID-19 Pandemic, how would you describe the intensity of your loneliness?
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: Comparing how you feel now to how you felt before the COVID-19 Pandemic, how would you describe the intensity of your loneliness?
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Comparing how you feel now to how you felt before the COVID-19 Pandemic, how would you describe the intensity of your loneliness?
# ----------------------------------------------------------------------
#
# Number of NA: 6911
# LONELY_change_pre_covid
# Somewhat more lonely    1169
# About the same           902
# Much more lonely         679
# Somewhat less lonely     236
# Much less lonely         121
# Name: count, dtype: int64
#
# ----------------- Information about: LONELY_miss_fun -----------------
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: When you have felt lonely, what did you miss most? (Check all that apply) - Selected Choice - Fun and laughter / Leisure
# ----------------------------------------------------------------------
#
# Number of NA: 7793
# LONELY_miss_fun
# Fun and laughter / Leisure    1134
# Not Selected                  1091
# Name: count, dtype: int64
#
# ------- Information about: LONELY_miss_meaningful_conversation -------
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: When you have felt lonely, what did you miss most? (Check all that apply) - Selected Choice - Meaningful conversation
# ----------------------------------------------------------------------
#
# Number of NA: 7793
# LONELY_miss_meaningful_conversation
# Meaningful conversation    1183
# Not Selected               1042
# Name: count, dtype: int64
#
# ---------------- Information about: LONELY_miss_touch ----------------
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: When you have felt lonely, what did you miss most? (Check all that apply) - Selected Choice - Physical touch/hug, affection
# ----------------------------------------------------------------------
#
# Number of NA: 7793
# LONELY_miss_touch
# Physical touch/hug, affection    1149
# Not Selected                     1076
# Name: count, dtype: int64
#
# ------------- Information about: LONELY_miss_hanging_out -------------
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: When you have felt lonely, what did you miss most? (Check all that apply) - Selected Choice - Being with other people/ hanging out
# ----------------------------------------------------------------------
#
# Number of NA: 7793
# LONELY_miss_hanging_out
# Being with other people/ hanging out    1199
# Not Selected                            1026
# Name: count, dtype: int64
#
# ------------- Information about: LONELY_miss_understand --------------
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: When you have felt lonely, what did you miss most? (Check all that apply) - Selected Choice - Someone to understand me
# ----------------------------------------------------------------------
#
# Number of NA: 7793
# LONELY_miss_understand
# Not Selected                1537
# Someone to understand me     688
# Name: count, dtype: int64
#
# ---------------- Information about: LONELY_miss_doing ----------------
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: When you have felt lonely, what did you miss most? (Check all that apply) - Selected Choice - Doing something with other people
# ----------------------------------------------------------------------
#
# Number of NA: 7793
# LONELY_miss_doing
# Not Selected                         1209
# Doing something with other people    1016
# Name: count, dtype: int64
#
# -------------- Information about: LONELY_miss_mattering --------------
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: When you have felt lonely, what did you miss most? (Check all that apply) - Selected Choice - Mattering to someone/being able to help someone
# ----------------------------------------------------------------------
#
# Number of NA: 7793
# LONELY_miss_mattering
# Not Selected                                       1544
# Mattering to someone/being able to help someone     681
# Name: count, dtype: int64
#
# ----------- Information about: LONELY_miss_something_else ------------
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: When you have felt lonely, what did you miss most? (Check all that apply) - Selected Choice - Something else
# ----------------------------------------------------------------------
#
# Number of NA: 7793
# LONELY_miss_something_else
# Not Selected      2108
# Something else     117
# Name: count, dtype: int64
#
# --------- Information about: LONELY_miss_something_else_text ---------
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: When you have felt lonely, what did you miss most? (Check all that apply) - Something else - Text
# ----------------------------------------------------------------------
#
# Number of NA: 9944
# LONELY_miss_something_else_text
# sex                                                                                                                                                                              2
# being filled with purpose                                                                                                                                                        1
# meeting up with others at the local pool                                                                                                                                         1
# Church, live music, cultural events                                                                                                                                              1
# I miss having a partner who I can talk to and share my life. Someone who listens to what I have to say and makes me feel apart of the relationship I am suppose to be having.    1
#                                                                                                                                                                                 ..
# intimacy                                                                                                                                                                         1
# Riding motorcycle in a group                                                                                                                                                     1
# Feeling like I had a future.                                                                                                                                                     1
# travel                                                                                                                                                                           1
# Rencontrer de nouvelles personnes                                                                                                                                                1
# Name: count, Length: 73, dtype: int64
#
# --------------- Information about: LONELY_others_aware ---------------
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: Generally speaking, do you think others are aware of the extent to which you feel lonely or connected?
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: Generally speaking, do you think others are aware of the extent to which you feel lonely or connected?
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Generally speaking, do you think others are aware of the extent to which you feel lonely or connected?
# ----------------------------------------------------------------------
#
# Number of NA: 6922
# LONELY_others_aware
# Probably No       1539
# Probably Yes       912
# Definitely No      520
# Definitely Yes     125
# Name: count, dtype: int64
#
# ------- Information about: LONELY_steptoe_isolation_index_kids -------
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: Do you have KIDS with whom you see, talk to, text, email, or write to at least once a month?
# ----------------------------------------------------------------------
#
# Number of NA: 7364
# LONELY_steptoe_isolation_index_kids
# Yes    1746
# No      908
# Name: count, dtype: int64
#
# ---- Information about: LONELY_steptoe_isolation_index_other_fam -----
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: Do you have OTHER FAMILY MEMBERS with whom you see, talk to, text, email, or write to at least once a month?
# ----------------------------------------------------------------------
#
# Number of NA: 7367
# LONELY_steptoe_isolation_index_other_fam
# Yes    2352
# No      299
# Name: count, dtype: int64
#
# ----- Information about: LONELY_steptoe_isolation_index_friends ------
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: Do you have OTHER FRIENDS with whom you see, talk to, text, email, or write to at least once a month?
# ----------------------------------------------------------------------
#
# Number of NA: 7374
# LONELY_steptoe_isolation_index_friends
# Yes    2360
# No      284
# Name: count, dtype: int64
#
# --- Information about: LONELY_existential_loneliness_scale_outlook ---
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: Please use the following scale to rate the extent to which you agree or disagree with each of the following statements IN GENERAL. - I usually feel like people share my outlook on life.
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: Please use the following scale to rate the extent to which you agree or disagree with each of the following statements IN GENERAL. - I usually feel like people share my outlook on life.
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Please use the following scale to rate the extent to which you agree or disagree with each of the following statements IN GENERAL. - I usually feel like people share my outlook on life.
# ----------------------------------------------------------------------
#
# Number of NA: 8380
# LONELY_existential_loneliness_scale_outlook
# 5                        349
# 6                        245
# 4                        232
# 3                        210
# 7                        193
# 2                        124
# 8                        100
# (9) Strongly Disagree     96
# (1) Strongly Agree        89
# Name: count, dtype: int64
#
# -- Information about: LONELY_existential_loneliness_scale_reactions --
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: Please use the following scale to rate the extent to which you agree or disagree with each of the following statements IN GENERAL. - I often have the same reactions to things that other people around me do.
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: Please use the following scale to rate the extent to which you agree or disagree with each of the following statements IN GENERAL. - I often have the same reactions to things that other people around me do.
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Please use the following scale to rate the extent to which you agree or disagree with each of the following statements IN GENERAL. - I often have the same reactions to things that other people around me do.
# ----------------------------------------------------------------------
#
# Number of NA: 8387
# LONELY_existential_loneliness_scale_reactions
# 5                        331
# 6                        272
# 7                        236
# 4                        221
# 3                        209
# 2                        128
# 8                         87
# (9) Strongly Disagree     78
# (1) Strongly Agree        69
# Name: count, dtype: int64
#
# - Information about: LONELY_existential_loneliness_scale_environment -
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: Please use the following scale to rate the extent to which you agree or disagree with each of the following statements IN GENERAL. - People around me tend to react to things in our environment the same way I do.
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: Please use the following scale to rate the extent to which you agree or disagree with each of the following statements IN GENERAL. - People around me tend to react to things in our environment the same way I do.
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Please use the following scale to rate the extent to which you agree or disagree with each of the following statements IN GENERAL. - People around me tend to react to things in our environment the same way I do.
# ----------------------------------------------------------------------
#
# Number of NA: 8388
# LONELY_existential_loneliness_scale_environment
# 5                        338
# 6                        262
# 4                        238
# 7                        228
# 3                        223
# 2                        107
# 8                         84
# (9) Strongly Disagree     80
# (1) Strongly Agree        70
# Name: count, dtype: int64
#
# ---- Information about: LONELY_existential_loneliness_scale_share ----
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: Please use the following scale to rate the extent to which you agree or disagree with each of the following statements IN GENERAL. - People do not often share my perspective.
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: Please use the following scale to rate the extent to which you agree or disagree with each of the following statements IN GENERAL. - People do not often share my perspective.
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Please use the following scale to rate the extent to which you agree or disagree with each of the following statements IN GENERAL. - People do NOT often share my perspective.
# ----------------------------------------------------------------------
#
# Number of NA: 8387
# LONELY_existential_loneliness_scale_share
# 5                        333
# 7                        252
# 6                        247
# 4                        239
# 3                        176
# 8                        131
# 2                         99
# (9) Strongly Disagree     77
# (1) Strongly Agree        77
# Name: count, dtype: int64
#
# - Information about: LONELY_existential_loneliness_scale_understand --
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: Please use the following scale to rate the extent to which you agree or disagree with each of the following statements IN GENERAL. - Other people usually do not understand my experiences.
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: Please use the following scale to rate the extent to which you agree or disagree with each of the following statements IN GENERAL. - Other people usually do not understand my experiences.
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Please use the following scale to rate the extent to which you agree or disagree with each of the following statements IN GENERAL. - Other people usually do NOT understand my experiences.
# ----------------------------------------------------------------------
#
# Number of NA: 8389
# LONELY_existential_loneliness_scale_understand
# 5                        340
# 6                        238
# 7                        224
# 4                        215
# 3                        187
# 8                        132
# 2                        122
# (1) Strongly Agree        91
# (9) Strongly Disagree     80
# Name: count, dtype: int64
#
# -- Information about: LONELY_existential_loneliness_scale_same_take --
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: Please use the following scale to rate the extent to which you agree or disagree with each of the following statements IN GENERAL. - People often have the same œtake or perspective on things that I do.
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: Please use the following scale to rate the extent to which you agree or disagree with each of the following statements IN GENERAL. - People often have the same œtake or perspective on things that I do.
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Please use the following scale to rate the extent to which you agree or disagree with each of the following statements IN GENERAL. - People often have the same œtake or perspective on things that I do.
# ----------------------------------------------------------------------
#
# Number of NA: 8392
# LONELY_existential_loneliness_scale_same_take
# 5                        354
# 6                        265
# 4                        245
# 7                        215
# 3                        199
# 2                        113
# 8                        101
# (1) Strongly Agree        69
# (9) Strongly Disagree     65
# Name: count, dtype: int64
#
# ---------------- Information about: LONELY_phenotype -----------------
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: Most people feel lonely at least some of the time. Others experience consistently strong feelings of loneliness. Which of the options below BEST describe your experience with loneliness?
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Most people feel lonely at least some of the time. Others experience consistently strong feelings of loneliness. Which of the options below BEST describe your experience with loneliness?
# ----------------------------------------------------------------------
#
# Number of NA: 9574
# LONELY_phenotype
# I experience intermittent periods where sometimes I feel lonely and other times I do not.    175
# I feel lonely only on occasion.                                                              139
# I never really feel lonely.                                                                   77
# I am lonely all of the time and its been this way for along time.                             29
# I am lonely all of the time, but I haven't always felt this way.                              24
# Name: count, dtype: int64
#
# ------------ Information about: LONELY_comparison_others -------------
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: How would you describe your loneliness compared to others?
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: How would you describe your loneliness compared to others?
# ----------------------------------------------------------------------
#
# Number of NA: 9576
# LONELY_comparison_others
# I am SOMEWHAT MORE lonely than other people    128
# I am ABOUT THE SAME as everyone else           116
# I am SOMEWHAT LESS lonely than other people     84
# I am MUCH LESS lonely than other people         79
# I am MUCH MORE lonely than other people         35
# Name: count, dtype: int64
#
# ------------ Information about: LONELY_change_last_summer ------------
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: Comparing how you feel now to how you felt last summer, how would you describe the intensity of your loneliness?
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cross -------------------------
#  Question: Comparing how you feel now to how you felt last summer, how would you describe the intensity of your loneliness?
# ----------------------------------------------------------------------
#
# Number of NA: 5406
# LONELY_change_last_summer
# About the same          1984
# Somewhat more lonely     862
# Somewhat less lonely     789
# Much less lonely         514
# Much more lonely         463
# Name: count, dtype: int64
#
#  Information about: VOLUNTEERISM_volunteer_functions_inventory_less_lonely
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: Please indicate how important or accurate each of the 30 possible reasons for volunteering were for you in doing volunteer work. - By volunteering I feel less lonely.
# ----------------------------------------------------------------------
#
# Number of NA: 8988
# VOLUNTEERISM_volunteer_functions_inventory_less_lonely
# -4                                    227
# -5                                    215
# -3                                    144
# -6                                    140
# (1) Not at all important/ accurate    117
# -2                                     95
# (7) Extremely important/ accurate      92
# Name: count, dtype: int64
#
# ------ Information about: CONNECTION_benefits_new_people_lonely ------
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: From your experience, what benefits are there to meeting new people? (Check all that apply) - Selected Choice - Helps me feel less lonely
# ----------------------------------------------------------------------
#
# Number of NA: 9490
# CONNECTION_benefits_new_people_lonely
# Not Selected                 350
# Helps me feel less lonely    178
# Name: count, dtype: int64
#
# ---------- Information about: LONELY_chronic_lonely_others -----------
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: How many people do you know who continually experience loneliness or social isolation on an ongoing basis?
# ----------------------------------------------------------------------
#
# Number of NA: 9525
# LONELY_chronic_lonely_others
# 0.0     162
# 2.0     104
# 1.0      82
# 3.0      43
# 4.0      32
# 5.0      21
# 6.0      12
# 10.0     10
# 7.0       8
# 12.0      5
# 11.0      3
# 8.0       3
# 9.0       2
# 20.0      2
# 14.0      1
# 50.0      1
# 13.0      1
# 30.0      1
# Name: count, dtype: int64
#
# ------------- Information about: LONELY_lifecourse_5to12 -------------
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Experiences of loneliness can change over your life. Generally speaking, how often would you say you have been lonely during each of the times listed below: - Ages 5 to 12 (Elementary school aged)
# ----------------------------------------------------------------------
#
# Number of NA: 10018
# Series([], Name: count, dtype: int64)
#
# ------------ Information about: LONELY_lifecourse_13to18 -------------
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Experiences of loneliness can change over your life. Generally speaking, how often would you say you have been lonely during each of the times listed below: - Ages 13 to 18 (High school aged)
# ----------------------------------------------------------------------
#
# Number of NA: 10018
# Series([], Name: count, dtype: int64)
#
# ------------ Information about: LONELY_lifecourse_19to24 -------------
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Experiences of loneliness can change over your life. Generally speaking, how often would you say you have been lonely during each of the times listed below: - Ages 19 to 24 (Emerging adults)
# ----------------------------------------------------------------------
#
# Number of NA: 10018
# Series([], Name: count, dtype: int64)
#
# ------------ Information about: LONELY_lifecourse_25to30 -------------
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Experiences of loneliness can change over your life. Generally speaking, how often would you say you have been lonely during each of the times listed below: - Ages 25 to 30 (Young adults)
# ----------------------------------------------------------------------
#
# Number of NA: 10018
# Series([], Name: count, dtype: int64)
#
# -------------- Information about: LONELY_lifecourse_30s --------------
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Experiences of loneliness can change over your life. Generally speaking, how often would you say you have been lonely during each of the times listed below: - Your 30's
# ----------------------------------------------------------------------
#
# Number of NA: 10018
# Series([], Name: count, dtype: int64)
#
# -------------- Information about: LONELY_lifecourse_40s --------------
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Experiences of loneliness can change over your life. Generally speaking, how often would you say you have been lonely during each of the times listed below: - Your 40's
# ----------------------------------------------------------------------
#
# Number of NA: 10018
# Series([], Name: count, dtype: int64)
#
# -------------- Information about: LONELY_lifecourse_50s --------------
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Experiences of loneliness can change over your life. Generally speaking, how often would you say you have been lonely during each of the times listed below: - Your 50's
# ----------------------------------------------------------------------
#
# Number of NA: 10018
# Series([], Name: count, dtype: int64)
#
# -------------- Information about: LONELY_lifecourse_60s --------------
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Experiences of loneliness can change over your life. Generally speaking, how often would you say you have been lonely during each of the times listed below: - Your 60's
# ----------------------------------------------------------------------
#
# Number of NA: 10018
# Series([], Name: count, dtype: int64)
#
# -------------- Information about: LONELY_lifecourse_70s --------------
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Experiences of loneliness can change over your life. Generally speaking, how often would you say you have been lonely during each of the times listed below: - Your 70's
# ----------------------------------------------------------------------
#
# Number of NA: 10018
# Series([], Name: count, dtype: int64)
#
# -------------- Information about: LONELY_lifecourse_80s --------------
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Experiences of loneliness can change over your life. Generally speaking, how often would you say you have been lonely during each of the times listed below: - Your 80's
# ----------------------------------------------------------------------
#
# Number of NA: 10018
# Series([], Name: count, dtype: int64)
#
# ------------------- Information about: LONELY_last -------------------
# ------------------------ Dataset: 2023_cohort ------------------------
# --------- Question: When was the last time you felt lonely? ----------
# ----------------------------------------------------------------------
#
# Number of NA: 10018
# Series([], Name: count, dtype: int64)
#
#  Information about: NUTRITION_three_factor_eating_questionnaire_eat_when_lonely
# ------------------------ Dataset: 2023_cross -------------------------
#  Question: Please read each statement and select from the multiple choice options the answer that indicates the frequency with which you  find yourself feeling or experiencing what is being described in the statements below. - When I feel lonely, I console myself by eating.
# ----------------------------------------------------------------------
#
# Number of NA: 9715
# NUTRITION_three_factor_eating_questionnaire_eat_when_lonely
# Definitely false    96
# Mostly false        90
# Mostly true         87
# Definitely true     30
# Name: count, dtype: int64
#
# ------- Information about: LONELY_ucla_loneliness_scale_score --------
# -------------------- No associated question found --------------------
# Number of NA: 6784
# LONELY_ucla_loneliness_scale_score
# 6.0    763
# 5.0    666
# 3.0    506
# 4.0    406
# 7.0    367
# 9.0    333
# 8.0    193
# Name: count, dtype: int64
#
# ----- Information about: LONELY_ucla_loneliness_scale_score_y_n ------
# -------------------- No associated question found --------------------
# Number of NA: 6784
# LONELY_ucla_loneliness_scale_score_y_n
# Yes (6-9)    1656
# No (3-5)     1578
# Name: count, dtype: int64
#
#  Information about: LONELY_dejong_emotional_social_loneliness_scale_score
# -------------------- No associated question found --------------------
# Number of NA: 2391
# LONELY_dejong_emotional_social_loneliness_scale_score
# 6.0    1729
# 5.0    1523
# 4.0    1223
# 3.0    1185
# 2.0     871
# 1.0     693
# 0.0     403
# Name: count, dtype: int64
#
#  Information about: LONELY_dejong_emotional_loneliness_sub_scale_score
# -------------------- No associated question found --------------------
# Number of NA: 2346
# LONELY_dejong_emotional_loneliness_sub_scale_score
# 3.0    3042
# 2.0    1820
# 1.0    1680
# 0.0    1130
# Name: count, dtype: int64
#
# - Information about: LONELY_dejong_social_loneliness_sub_scale_score -
# -------------------- No associated question found --------------------
# Number of NA: 2304
# LONELY_dejong_social_loneliness_sub_scale_score
# 3.0    3436
# 2.0    1626
# 0.0    1533
# 1.0    1119
# Name: count, dtype: int64
#
#  Information about: LONELY_dejong_emotional_social_loneliness_scale_score_y_n
# -------------------- No associated question found --------------------
# Number of NA: 2391
# LONELY_dejong_emotional_social_loneliness_scale_score_y_n
# Yes (2-6)    6531
# No (0-1)     1096
# Name: count, dtype: int64
#
#  Information about: LONELY_dejong_emotional_loneliness_sub_scale_score_y_n
# -------------------- No associated question found --------------------
# Number of NA: 2346
# LONELY_dejong_emotional_loneliness_sub_scale_score_y_n
# Yes (1-3)    6542
# No (0)       1130
# Name: count, dtype: int64
#
#  Information about: LONELY_dejong_social_loneliness_sub_scale_score_y_n
# -------------------- No associated question found --------------------
# Number of NA: 2304
# LONELY_dejong_social_loneliness_sub_scale_score_y_n
# Yes (1-3)    6181
# No (0)       1533
# Name: count, dtype: int64
#
#  Information about: LONELY_existential_loneliness_scale_outlook_corrected
# -------------------- No associated question found --------------------
# Number of NA: 8380
# LONELY_existential_loneliness_scale_outlook_corrected
# 5                        349
# 4                        245
# 6                        232
# 7                        210
# 3                        193
# 8                        124
# 2                        100
# (1) Strongly Agree        96
# (9) Strongly Disagree     89
# Name: count, dtype: int64
#
#  Information about: LONELY_existential_loneliness_scale_reactions_corrected
# -------------------- No associated question found --------------------
# Number of NA: 8387
# LONELY_existential_loneliness_scale_reactions_corrected
# 5                        331
# 4                        272
# 3                        236
# 6                        221
# 7                        209
# 8                        128
# 2                         87
# (1) Strongly Agree        78
# (9) Strongly Disagree     69
# Name: count, dtype: int64
#
#  Information about: LONELY_existential_loneliness_scale_environment_corrected
# -------------------- No associated question found --------------------
# Number of NA: 8388
# LONELY_existential_loneliness_scale_environment_corrected
# 5                        338
# 4                        262
# 6                        238
# 3                        228
# 7                        223
# 8                        107
# 2                         84
# (1) Strongly Agree        80
# (9) Strongly Disagree     70
# Name: count, dtype: int64
#
#  Information about: LONELY_existential_loneliness_scale_same_take_corrected
# -------------------- No associated question found --------------------
# Number of NA: 8392
# LONELY_existential_loneliness_scale_same_take_corrected
# 5                        354
# 4                        265
# 6                        245
# 3                        215
# 7                        199
# 8                        113
# 2                        101
# (9) Strongly Disagree     69
# (1) Strongly Agree        65
# Name: count, dtype: int64
#
#  Information about: LONELY_existential_loneliness_scale_share_corrected
# -------------------- No associated question found --------------------
# Number of NA: 8387
# LONELY_existential_loneliness_scale_share_corrected
# 5                        333
# 3                        252
# 4                        247
# 6                        239
# 7                        176
# 2                        131
# 8                         99
# (1) Strongly Agree        77
# (9) Strongly Disagree     77
# Name: count, dtype: int64
#
#  Information about: LONELY_existential_loneliness_scale_understand_corrected
# -------------------- No associated question found --------------------
# Number of NA: 8389
# LONELY_existential_loneliness_scale_understand_corrected
# 5                        340
# 4                        238
# 3                        224
# 6                        215
# 7                        187
# 2                        132
# 8                        122
# (9) Strongly Disagree     91
# (1) Strongly Agree        80
# Name: count, dtype: int64
#
# ---- Information about: LONELY_existential_loneliness_scale_score ----
# -------------------- No associated question found --------------------
# Number of NA: 8413
# LONELY_existential_loneliness_scale_score
# 30.0    136
# 32.0    108
# 28.0     97
# 31.0     94
# 29.0     91
# 34.0     90
# 33.0     83
# 27.0     71
# 36.0     61
# 35.0     58
# 26.0     51
# 25.0     51
# 24.0     50
# 38.0     49
# 23.0     44
# 22.0     42
# 37.0     34
# 40.0     31
# 21.0     29
# 20.0     28
# 39.0     24
# 19.0     24
# 42.0     23
# 18.0     23
# 16.0     22
# 17.0     22
# 45.0     17
# 15.0     16
# 41.0     15
# 14.0     15
# 44.0     13
# 12.0     12
# 54.0     12
# 46.0     10
# 13.0      9
# 43.0      8
# 11.0      7
# 6.0       6
# 48.0      5
# 47.0      4
# 50.0      3
# 52.0      3
# 7.0       3
# 51.0      3
# 49.0      2
# 10.0      2
# 9.0       2
# 8.0       2
# Name: count, dtype: int64
