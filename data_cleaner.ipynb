# %% [markdown]
# # Data cleaner + Variable Searcher
# ### Add to the beginning of your notebook
# **Imports the data and does the recommended cleaning. Adds 3 functions modified from variable searcher to return detailed information about variables.**
# Variable names:
# - cols: the list of variables
# - data: the original dataframe
#
# Functions:
# - get_matching_keywords: takes a list of strings and returns all variables who contain at least one keyword
# - get_var_details: takes a variable name and returns a list of questions corresponding to which dataset the variable is from
# - get_column_info: takes a variable name and returns a list of every question associated with the variable as well as information about the type and amount of responses to the question.

# %%
import pandas as pd
cols = pd.read_csv("var_names.csv")
data = pd.read_csv('CSCS_data_anon.csv', low_memory=False,
                        na_values=["9999", "", " ", "Presented but no response", "NA"])
empty = (data.isna().sum()==data.shape[0])
data = data[empty.index[~empty]] # keep non empty columns only
data = data[data.REMOVE_case=='No'].copy()

# %%
def get_matching_keywords(keywords: list[str]) -> list[str]:
    """
    Returns the names of the columns whose string contains any of the keywords
    """
    global data
    return [col for col in data.columns if any(keyword.lower() in col.lower() for keyword in keywords)]

def get_var_details(var_name: str) -> list[tuple[str, str]]:
    """
    Returns a list of pairs detailing the question and datasets 
    corresponding to the given variable name
    """
    global cols
    filtered_data = cols[cols['new_var'] == var_name]
    
    info = []
    result: pd.DataFrame = filtered_data[['new_var', 'text', 'dataset']]
    for index, row in result.iterrows():
        info.append((row['text'], row['dataset']))

    return info

def get_column_info(column_name: str) -> None:
    """
    Returns information about a given column
    """
    global data, cols
    column_info: pd.DataFrame = data[column_name]
    print(f"{' Information about: ' + column_name + ' ':-^70}")
    details = get_var_details(column_name)
    if not details: print(f"{' No associated question found ':-^70}")
    for question, dataset in details:
        print(f"{' Dataset: ' + dataset + ' ':-^70}")
        print(f"{' Question: ' + question + ' ':-^70}")
        print(f"{'':-^70}\n")
    print(f"Number of NA: {column_info.isna().sum()}")
    print(column_info.value_counts())
    print("")

def get_datasets(column_name: str) -> list[str]:
    """
    Returns a list of datasets a variable name is found in
    """
    datasets = []
    for question, dataset in get_var_details(column_name):
        datasets.append(dataset)
    return datasets

# %%
# Example usage
words = ["WORK_friend"]
to_examine = get_matching_keywords(words)
for col in to_examine:
    get_column_info(col)
# Out:
# ------- Information about: VOLUNTEERISM_volunteer_work_friends -------
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: Which of the following is true about your volunteer work? (Check all that apply) - I volunteered with friends.
# ----------------------------------------------------------------------
#
# Number of NA: 8978
# VOLUNTEERISM_volunteer_work_friends
# Not Selected                   579
# I volunteered with friends.    461
# Name: count, dtype: int64
#
#  Information about: CONNECTION_lubben_social_network_friends_subscale_see
# ------------------------ Dataset: 2023_cross -------------------------
#  Question: Please answer each of the following questions about the people you know: - How many of your friends do you see or hear from at least once a month?
# ----------------------------------------------------------------------
#
# Number of NA: 8143
# CONNECTION_lubben_social_network_friends_subscale_see
# 2             428
# 1             338
# 3             298
# 4             222
# 5             190
# 6             134
# 10             92
# 8              53
# 7              33
# 12             28
# 15             17
# 20 or more     16
# 9              15
# 11              4
# 14              2
# 16              2
# 19              1
# 13              1
# 18              1
# Name: count, dtype: int64
#
#  Information about: CONNECTION_lubben_social_network_friends_subscale_feel_at_ease
# ------------------------ Dataset: 2023_cross -------------------------
#  Question: Please answer each of the following questions about the people you know: - How many friends do you feel at ease with that you can talk about private matters?
# ----------------------------------------------------------------------
#
# Number of NA: 8237
# CONNECTION_lubben_social_network_friends_subscale_feel_at_ease
# 2             492
# 1             434
# 3             303
# 4             193
# 5             134
# 6              84
# 8              40
# 7              34
# 10             30
# 20 or more     11
# 12              8
# 9               6
# 15              5
# 11              4
# 18              2
# 14              1
# Name: count, dtype: int64
#
#  Information about: CONNECTION_lubben_social_network_friends_subscale_call_for_help
# ------------------------ Dataset: 2023_cross -------------------------
#  Question: Please answer each of the following questions about the people you know: - How many friends do you feel close to such that you could call on them for help?
# ----------------------------------------------------------------------
#
# Number of NA: 8306
# CONNECTION_lubben_social_network_friends_subscale_call_for_help
# 2             425
# 1             410
# 3             314
# 4             197
# 5             121
# 6              86
# 10             42
# 8              40
# 7              34
# 20 or more     15
# 9              11
# 12              9
# 15              4
# 18              1
# 16              1
# 11              1
# 14              1
# Name: count, dtype: int64
#
# ---------------- Information about: WORK_friends_num -----------------
# ------------------------ Dataset: 2023_cross -------------------------
# ----- Question: How many friends do you have at your workplace? ------
# ----------------------------------------------------------------------
#
# Number of NA: 9892
# WORK_friends_num
# 0.0     94
# 1.0      8
# 3.0      8
# 2.0      7
# 5.0      3
# 4.0      3
# 10.0     2
# 6.0      1
# Name: count, dtype: int64

# %% [markdown]
# Interests:
# - CONNECTION_activities_meeting_work_p3m
# - CONNECTION_preferred_frequency_hang_out
# - CONNECTION_activities_visited_friends_p3m
# - CONNECTION_activities_new_friend_p3m / CONNECTION_activities_new_friend_last - DO busy people make new friends?
# - CONNECTION_social_days_friends_p7d_grouped / CONNECTION_social_days_friends_p7d
# - CONNECTION_social_time_friends_p7d_grouped / CONNECTION_social_time_friends_p7d
# - CONNECTION_preference_time_friends_grouped / CONNECTION_preference_time_friends
# - CONNECTION_meaningful_time_friends_grouped
# - CONNECTION_social_num_close_friends
# - CONNECTION_lubben_social_network_friends_subscale_see
#
# Money?
# - CONNECTION_close_friends_same_more_money
# - CONNECTION_close_friends_same_less_money
# - CONNECTION_close_friends_same_money
# - FRIENDSHIP_hall_friendship_standards_self_money
#
# Humor
# - FRIENDSHIP_hall_friendship_standards_self_sense_of_humor
#
# Work friends
# - WORK_friends_num

# %%
to_examine = ["CONNECTION_activities_meeting_work_p3m", "CONNECTION_preferred_frequency_hang_out", "CONNECTION_activities_visited_friends_p3m", "CONNECTION_activities_new_friend_p3m", "CONNECTION_activities_new_friend_last", "CONNECTION_social_days_friends_p7d_grouped", "CONNECTION_social_days_friends_p7d", "CONNECTION_social_time_friends_p7d_grouped", "CONNECTION_social_time_friends_p7d", "CONNECTION_preference_time_friends_grouped", "CONNECTION_preference_time_friends", "CONNECTION_meaningful_time_friends_groupe", "CONNECTION_social_num_close_friends", "CONNECTION_lubben_social_network_friends_subscale_see"]
to_examine = get_matching_keywords(to_examine)
for col in to_examine:
    get_column_info(col)
# Out:
# ---- Information about: CONNECTION_activities_visited_friends_p3m ----
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: In the PAST THREE MONTH, how often have you... - visited with FRIENDS at your / their home?
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: In the PAST THREE MONTH, how often have you... - visited with FRIENDS at your / their home?
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: In the PAST THREE MONTH, how often have you... - visited with FRIENDS at your / their home?
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cross -------------------------
#  Question: In the PAST THREE MONTH, how often have you... - visited with FRIENDS at your or their home?
# ----------------------------------------------------------------------
#
# Number of NA: 4047
# CONNECTION_activities_visited_friends_p3m
# Not in the past three months    1581
# Less than monthly               1172
# A few times a month             1170
# Monthly                          876
# Weekly                           736
# A few times a week               342
# Daily or almost daily             94
# Name: count, dtype: int64
#
# ----- Information about: CONNECTION_activities_meeting_work_p3m ------
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: In the PAST THREE MONTH, how often have you... - attended a meeting at work?
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: In the PAST THREE MONTH, how often have you... - attended a meeting at work?
# ----------------------------------------------------------------------
#
# Number of NA: 6651
# CONNECTION_activities_meeting_work_p3m
# Not in the past three months    1193
# A few times a month              533
# Weekly                           515
# Monthly                          421
# Less than monthly                269
# A few times a week               262
# Daily or almost daily            174
# Name: count, dtype: int64
#
# ------ Information about: CONNECTION_activities_new_friend_p3m -------
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: In the PAST THREE MONTH, how often have you... - made a new friend?
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: In the PAST THREE MONTH, how often have you... - made a new friend?
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: In the PAST THREE MONTH, how often have you... - made a new friend?
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cross -------------------------
#  Question: In the PAST THREE MONTH, how often have you... - made a new friend?
# ----------------------------------------------------------------------
#
# Number of NA: 4052
# CONNECTION_activities_new_friend_p3m
# Not in the past three months    3074
# Less than monthly               1194
# Monthly                          594
# A few times a month              565
# Weekly                           322
# A few times a week               157
# Daily or almost daily             60
# Name: count, dtype: int64
#
# --- Information about: CONNECTION_social_num_close_friends_grouped ---
# ------------------------ Dataset: 2021_cross -------------------------
# ----------- Question: How many close friends do you have? ------------
# ----------------------------------------------------------------------
#
# Number of NA: 3028
# CONNECTION_social_num_close_friends_grouped
# 3–4          2558
# 1–2          2263
# 5 or more    2169
# Name: count, dtype: int64
#
# --- Information about: CONNECTION_social_days_friends_p7d_grouped ----
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: In the PAST WEEK, how many days did you spend at least 5 minutes socializing with people from the following groups? - Friends
# ----------------------------------------------------------------------
#
# Number of NA: 1849
# CONNECTION_social_days_friends_p7d_grouped
# Some days (1 - 3 days)    4115
# Most days (4 - 6 days)    1925
# None (0 Days)             1272
# Every day (7 days)         857
# Name: count, dtype: int64
#
# --- Information about: CONNECTION_social_time_friends_p7d_grouped ----
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: In the PAST WEEK, how many hours in total did you spend socializing with others from the following groups? - Friends
# ----------------------------------------------------------------------
#
# Number of NA: 1919
# CONNECTION_social_time_friends_p7d_grouped
# 1 to 4 hours        2749
# 5 or more hours     2312
# Less than 1 hour    1647
# No time             1391
# Name: count, dtype: int64
#
# --- Information about: CONNECTION_preference_time_friends_grouped ----
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: How much time per week would you like to spend socializing with others from the following groups? - Friends
# ----------------------------------------------------------------------
#
# Number of NA: 4249
# CONNECTION_preference_time_friends_grouped
# 1 to 4 hours        2328
# 5 or more hours     2312
# Less than 1 hour     867
# No time              262
# Name: count, dtype: int64
#
# --- Information about: CONNECTION_meaningful_time_friends_grouped ----
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: Generally speaking, how much of your time spent with each of the following groups is meaningful and fulfilling? - Friends
# ----------------------------------------------------------------------
#
# Number of NA: 7217
# CONNECTION_meaningful_time_friends_grouped
# Most of the time    1214
# Some of the time     953
# All of the time      442
# None of the time     192
# Name: count, dtype: int64
#
# ------- Information about: CONNECTION_social_num_close_friends -------
# ------------------------ Dataset: 2022_cohort ------------------------
# ----------- Question: How many close friends do you have? ------------
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cross -------------------------
# ----------- Question: How many close friends do you have? ------------
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
# ----------- Question: How many close friends do you have? ------------
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cross -------------------------
# ----------- Question: How many close friends do you have? ------------
# ----------------------------------------------------------------------
#
# Number of NA: 5262
# CONNECTION_social_num_close_friends
# 3.0     855
# 2.0     795
# 4.0     587
# 5.0     526
# 1.0     488
# 0.0     443
# 6.0     359
# 10.0    183
# 8.0     155
# 7.0     141
# 12.0     57
# 9.0      47
# 20.0     39
# 15.0     26
# 11.0     17
# 18.0     10
# 13.0     10
# 14.0      7
# 16.0      6
# 17.0      4
# 19.0      1
# Name: count, dtype: int64
#
# ------- Information about: CONNECTION_social_days_friends_p7d --------
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: In the PAST SEVEN DAYS, how many days did you spend at least 5 minutes socializing with people from the following groups? - Friends
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: In the PAST WEEK, how many days did you spend at least 5 minutes socializing with people from the following groups? - Friends
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: In the PAST SEVEN DAYS, how many days did you spend at least 5 minutes socializing with people from the following groups? - Friends
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cross -------------------------
#  Question: In the PAST WEEK, how many days did you spend at least 5 minutes socializing with people from the following groups? - Friends
# ----------------------------------------------------------------------
#
# Number of NA: 4641
# CONNECTION_social_days_friends_p7d
# 2.0    1012
# 1.0     947
# 0.0     856
# 3.0     849
# 7.0     614
# 4.0     474
# 5.0     473
# 6.0     152
# Name: count, dtype: int64
#
# ------- Information about: CONNECTION_social_time_friends_p7d --------
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: In the PAST SEVEN DAYS, how many hours in total did you spend socializing with others from the following groups? - Friends
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: In the PAST WEEK, how many hours in total did you spend socializing with others from the following groups? - Friends
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: In the PAST SEVEN DAYS, how many hours in total did you spend socializing with others from the following groups? - Friends
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cross -------------------------
#  Question: In the PAST WEEK, how many hours in total did you spend socializing with others from the following groups? - Friends
# ----------------------------------------------------------------------
#
# Number of NA: 4716
# CONNECTION_social_time_friends_p7d
# 0.0      1012
# 1.0       723
# 2.0       680
# 3.0       527
# 4.0       442
# 5.0       390
# 10.0      284
# 6.0       223
# 7.0       170
# 8.0       164
# 12.0      102
# 20.0       81
# 9.0        73
# 15.0       70
# 30.0       48
# 11.0       45
# 14.0       33
# 13.0       33
# 16.0       29
# 24.0       23
# 25.0       18
# 40.0       15
# 17.0       11
# 18.0       11
# 28.0        5
# 48.0        5
# 27.0        5
# 60.0        4
# 39.0        4
# 35.0        4
# 21.0        4
# 22.0        4
# 70.0        4
# 19.0        4
# 100.0       4
# 75.0        3
# 36.0        3
# 50.0        3
# 33.0        3
# 44.0        3
# 23.0        3
# 41.0        3
# 32.0        3
# 45.0        3
# 96.0        2
# 38.0        2
# 37.0        2
# 29.0        2
# 46.0        2
# 47.0        2
# 92.0        1
# 80.0        1
# 95.0        1
# 26.0        1
# 49.0        1
# 31.0        1
# 34.0        1
# 57.0        1
# 63.0        1
# Name: count, dtype: int64
#
# ------- Information about: CONNECTION_preference_time_friends --------
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: How much time per week would you like to spend socializing with others from the following groups? - Friends
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: Ideally, how many hours per week would you like to spend socializing with each of the following groups? - Friends
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: How much time per week would you like to spend socializing with others from the following groups? - Friends
# ----------------------------------------------------------------------
#
# Number of NA: 7040
# CONNECTION_preference_time_friends
# 2.0      374
# 4.0      329
# 3.0      325
# 5.0      315
# 6.0      239
# 10.0     233
# 1.0      214
# 8.0      163
# 7.0      123
# 0.0      111
# 20.0      81
# 12.0      70
# 15.0      62
# 14.0      59
# 30.0      38
# 9.0       34
# 11.0      25
# 13.0      18
# 24.0      16
# 18.0      13
# 40.0      13
# 21.0      12
# 16.0      12
# 25.0      11
# 17.0       6
# 22.0       5
# 36.0       5
# 28.0       5
# 35.0       5
# 100.0      4
# 60.0       4
# 70.0       4
# 26.0       4
# 168.0      4
# 45.0       4
# 50.0       4
# 23.0       3
# 80.0       3
# 27.0       2
# 19.0       2
# 59.0       2
# 29.0       2
# 41.0       2
# 39.0       2
# 33.0       2
# 38.0       2
# 44.0       2
# 34.0       1
# 75.0       1
# 48.0       1
# 111.0      1
# 69.0       1
# 31.0       1
# 42.0       1
# 130.0      1
# 55.0       1
# 120.0      1
# Name: count, dtype: int64
#
# ------ Information about: CONNECTION_activities_new_friend_last ------
# ------------------------ Dataset: 2022_cross -------------------------
# ----- Question: When was the last time you - made a new friend? ------
# ----------------------------------------------------------------------
#
# Number of NA: 7082
# CONNECTION_activities_new_friend_last
# Not in the past three months     1471
# One to three months ago           304
# In the past month                 302
# In the past week                  239
# In the past two or three days     206
# In the past two weeks             191
# Yesterday                         137
# Earlier today                      86
# Name: count, dtype: int64
#
# ----- Information about: CONNECTION_social_num_close_friends_p3m -----
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: Over the past three months, how many people belonging to each of following categories have you spent time socializing with? Note: Please provide your best estimates of the number of people you spent socializing with belonging to each category. As you assign each person you regularly spent time with, please assign them to ONLY one of the categories below. If a person belongs to multiple categories, choose the option that BEST matches your connection with this person. - Close friends
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cross -------------------------
#  Question: Over the past three months, how many people belonging to each of the following categories have you spent time socializing with?  Note: Please provide your best estimates of the number of people you spent socializing with belonging to each category. As you assign each person you regularly spent time with, please assign them to ONLY one of the categories below. If a person belongs to multiple categories, choose the option that BEST matches your connection with this person. - Close friends
# ----------------------------------------------------------------------
#
# Number of NA: 5489
# CONNECTION_social_num_close_friends_p3m
# 2.0     846
# 1.0     749
# 0.0     656
# 3.0     604
# 4.0     404
#        ...
# 49.0      1
# 27.0      1
# 51.0      1
# 67.0      1
# 63.0      1
# Name: count, Length: 67, dtype: int64
#
# ----- Information about: CONNECTION_preferred_frequency_hang_out -----
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: How frequently would you like to - have friends over to your place to hang out?
# ----------------------------------------------------------------------
#
# Number of NA: 9511
# CONNECTION_preferred_frequency_hang_out
# Every few weeks            112
# About once per week         90
# About once per month        70
# Every few months            53
# Every Few days              49
# Not at all                  48
# A few times a year          40
# Less than once per year     17
# About once per year         16
# Every day                   12
# Name: count, dtype: int64
#
#  Information about: CONNECTION_lubben_social_network_friends_subscale_see
# ------------------------ Dataset: 2023_cross -------------------------
#  Question: Please answer each of the following questions about the people you know: - How many of your friends do you see or hear from at least once a month?
# ----------------------------------------------------------------------
#
# Number of NA: 8143
# CONNECTION_lubben_social_network_friends_subscale_see
# 2             428
# 1             338
# 3             298
# 4             222
# 5             190
# 6             134
# 10             92
# 8              53
# 7              33
# 12             28
# 15             17
# 20 or more     16
# 9              15
# 11              4
# 14              2
# 16              2
# 19              1
# 13              1
# 18              1
# Name: count, dtype: int64
