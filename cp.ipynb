# %%
import pandas as pd
cols = pd.read_csv("var_names.csv")
data = pd.read_csv('CSCS_data_anon.csv', low_memory=False,
                        na_values=["9999", "", " ", "Presented but no response", "NA"])
empty = (data.isna().sum()==data.shape[0])
data = data[empty.index[~empty]] # keep non empty columns only
data_use = data[data.REMOVE_case=='No'].copy()

# %%
def get_matching_keywords(keywords: list[str]) -> list[str]:
    """
    Returns the names of the columns whose string contains any of the keywords
    """
    global data
    return [col for col in data.columns if any(keyword.lower() in col.lower() for keyword in keywords)]

def get_var_details(var_name: str) -> list[tuple[str, str]]:
    """
    Returns a list of pairs detailing the question and datasets 
    corresponding to the given variable name
    """
    global cols
    filtered_data = cols[cols['new_var'] == var_name]
    
    info = []
    result: pd.DataFrame = filtered_data[['new_var', 'text', 'dataset']]
    for index, row in result.iterrows():
        info.append((row['text'], row['dataset']))

    return info

def get_column_info(column_name: str) -> None:
    """
    Returns information about a given column
    """
    global data, cols
    column_info: pd.DataFrame = data[column_name]
    print(f"{' Information about: ' + column_name + ' ':-^70}")
    details = get_var_details(column_name)
    if not details: print(f"{' No associated question found ':-^70}")
    for question, dataset in details:
        print(f"{' Dataset: ' + dataset + ' ':-^70}")
        print(f"{' Question: ' + question + ' ':-^70}")
        print(f"{'':-^70}\n")
    print(f"Number of NA: {column_info.isna().sum()}")
    print(column_info.value_counts())
    print("")

# %%
words = ["sad"]
to_examine = get_matching_keywords(words)

for col in to_examine:
    get_column_info(col)
# Out:
# -- Information about: PSYCH_body_self_image_questionnaire_feel_sad ---
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: The statements below are all related to you and your body. Read each statement carefully, and decide how true the statement is for you. Use the rating scale below to indicate how true the statement is for you. - My naked body makes me feel sad.
# ----------------------------------------------------------------------
#
# Number of NA: 10661
# PSYCH_body_self_image_questionnaire_feel_sad
# Not at all true of myself       189
# Slightly true of myself         172
# About halfway true of myself    157
# Completely true of myself       132
# Mostly true of myself           120
# Name: count, dtype: int64
#
# ---------- Information about: PSYCH_big_five_inventory_sad -----------
# ------------------------ Dataset: 2022_cross -------------------------
# ----- Question: I see myself as someone who - is sad, depressed ------
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
# ----- Question: I see myself as someone who - is sad, depressed ------
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cross -------------------------
# ----- Question: I see myself as someone who - is sad, depressed ------
# ----------------------------------------------------------------------
#
# Number of NA: 8777
# PSYCH_big_five_inventory_sad
# Agree a little                612
# Disagree Strongly             594
# Neither agree nor disagree    441
# Agree Strongly                371
# Disagree A little             361
# Disagree                      121
# Strongly disagree              66
# Agree                          66
# Strongly Agree                 22
# Name: count, dtype: int64
#
#  Information about: NUTRITION_three_factor_eating_questionnaire_overeat_when_sad
# ------------------------ Dataset: 2023_cross -------------------------
#  Question: Please read each statement and select from the multiple choice options the answer that indicates the frequency with which you  find yourself feeling or experiencing what is being described in the statements below. - When I feel blue, I often overeat.
# ----------------------------------------------------------------------
#
# Number of NA: 11123
# NUTRITION_three_factor_eating_questionnaire_overeat_when_sad
# Mostly true         98
# Definitely false    84
# Mostly false        77
# Definitely true     49
# Name: count, dtype: int64

# %%
data_use.PSYCH_big_five_inventory_sad.value_counts()
# Out:
# PSYCH_big_five_inventory_sad
# Agree a little                597
# Disagree Strongly             576
# Agree Strongly                363
# Neither agree nor disagree    354
# Disagree A little             350
# Name: count, dtype: int64

# %%
words = ["burnout"]
to_examine = get_matching_keywords(words)

for col in to_examine:
    get_column_info(col)
# Out:
# --- Information about: WELLNESS_malach_pines_burnout_measure_tired ---
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: When you think about your life overall, how often do you feel the following? - Tired
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: When you think about your life overall, how often do you feel the following? - Tired
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: When you think about your work overall, how often do you feel the following? - Tired
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: When you think about your life overall, how often do you feel the following? - Tired
# ----------------------------------------------------------------------
#
# Number of NA: 6807
# WELLNESS_malach_pines_burnout_measure_tired
# Sometimes       1489
# Often            900
# Rarely           788
# Very Often       539
# Almost never     376
# Always           268
# Never            264
# Name: count, dtype: int64
#
#  Information about: WELLNESS_malach_pines_burnout_measure_disappointed
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: When you think about your life overall, how often do you feel the following? - Disappointed with people
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: When you think about your life overall, how often do you feel the following? - Disappointed with people
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: When you think about your work overall, how often do you feel the following? - Disappointed with people
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: When you think about your life overall, how often do you feel the following? - Disappointed with people
# ----------------------------------------------------------------------
#
# Number of NA: 6825
# WELLNESS_malach_pines_burnout_measure_disappointed
# Sometimes       1558
# Rarely          1026
# Often            712
# Almost never     492
# Very Often       418
# Never            257
# Always           143
# Name: count, dtype: int64
#
# - Information about: WELLNESS_malach_pines_burnout_measure_hopeless --
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: When you think about your life overall, how often do you feel the following? - Hopeless
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: When you think about your life overall, how often do you feel the following? - Hopeless
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: When you think about your work overall, how often do you feel the following? - Hopeless
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: When you think about your life overall, how often do you feel the following? - Hopeless
# ----------------------------------------------------------------------
#
# Number of NA: 6819
# WELLNESS_malach_pines_burnout_measure_hopeless
# Sometimes       1091
# Rarely          1082
# Almost never     876
# Never            754
# Often            477
# Very Often       222
# Always           110
# Name: count, dtype: int64
#
# -- Information about: WELLNESS_malach_pines_burnout_measure_trapped --
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: When you think about your life overall, how often do you feel the following? - Trapped
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: When you think about your life overall, how often do you feel the following? - Trapped
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: When you think about your work overall, how often do you feel the following? - Trapped
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: When you think about your life overall, how often do you feel the following? - Trapped
# ----------------------------------------------------------------------
#
# Number of NA: 6829
# WELLNESS_malach_pines_burnout_measure_trapped
# Sometimes       1146
# Rarely           896
# Never            831
# Almost never     785
# Often            518
# Very Often       272
# Always           154
# Name: count, dtype: int64
#
# - Information about: WELLNESS_malach_pines_burnout_measure_helpless --
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: When you think about your life overall, how often do you feel the following? - Helpless
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: When you think about your life overall, how often do you feel the following? - Helpless
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: When you think about your work overall, how often do you feel the following? - Helpless
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: When you think about your life overall, how often do you feel the following? - Helpless
# ----------------------------------------------------------------------
#
# Number of NA: 6835
# WELLNESS_malach_pines_burnout_measure_helpless
# Sometimes       1102
# Rarely          1000
# Never            856
# Almost never     774
# Often            500
# Very Often       240
# Always           124
# Name: count, dtype: int64
#
# - Information about: WELLNESS_malach_pines_burnout_measure_depressed -
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: When you think about your life overall, how often do you feel the following? - Depressed
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: When you think about your life overall, how often do you feel the following? - Depressed
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: When you think about your work overall, how often do you feel the following? - Depressed
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: When you think about your life overall, how often do you feel the following? - Depressed
# ----------------------------------------------------------------------
#
# Number of NA: 6824
# WELLNESS_malach_pines_burnout_measure_depressed
# Sometimes       1423
# Rarely           981
# Almost never     658
# Often            551
# Never            543
# Very Often       304
# Always           147
# Name: count, dtype: int64
#
# --- Information about: WELLNESS_malach_pines_burnout_measure_sick ----
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: When you think about your life overall, how often do you feel the following? - Physically weak or sickly
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: When you think about your life overall, how often do you feel the following? - Physically weak or sickly
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: When you think about your work overall, how often do you feel the following? - Physically weak or sickly
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: When you think about your life overall, how often do you feel the following? - Physically weak or sickly
# ----------------------------------------------------------------------
#
# Number of NA: 6824
# WELLNESS_malach_pines_burnout_measure_sick
# Sometimes       1198
# Rarely          1175
# Almost never     836
# Never            608
# Often            489
# Very Often       196
# Always           105
# Name: count, dtype: int64
#
# - Information about: WELLNESS_malach_pines_burnout_measure_worthless -
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: When you think about your life overall, how often do you feel the following? - Worthless or like a failure
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: When you think about your life overall, how often do you feel the following? - Worthless or like a failure
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: When you think about your work overall, how often do you feel the following? - Worthless or like a failure
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: When you think about your life overall, how often do you feel the following? - Worthless or like a failure
# ----------------------------------------------------------------------
#
# Number of NA: 6823
# WELLNESS_malach_pines_burnout_measure_worthless
# Never           1077
# Sometimes        942
# Rarely           941
# Almost never     899
# Often            413
# Very Often       216
# Always           120
# Name: count, dtype: int64
#
#  Information about: WELLNESS_malach_pines_burnout_measure_difficulty_sleeping
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: When you think about your life overall, how often do you feel the following? - Difficulties sleeping
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: When you think about your life overall, how often do you feel the following? - Difficulties sleeping
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: When you think about your work overall, how often do you feel the following? - Difficulties sleeping
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: When you think about your life overall, how often do you feel the following? - Difficulties sleeping
# ----------------------------------------------------------------------
#
# Number of NA: 6824
# WELLNESS_malach_pines_burnout_measure_difficulty_sleeping
# Sometimes       1220
# Rarely           876
# Often            717
# Almost never     679
# Never            478
# Very Often       397
# Always           240
# Name: count, dtype: int64
#
# -- Information about: WELLNESS_malach_pines_burnout_measure_had_it ---
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: When you think about your life overall, how often do you feel the following? - œIve had it
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: When you think about your life overall, how often do you feel the following? - œIve had it
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: When you think about your work overall, how often do you feel the following? - œIve had it
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: When you think about your life overall, how often do you feel the following? - I've had it
# ----------------------------------------------------------------------
#
# Number of NA: 6837
# WELLNESS_malach_pines_burnout_measure_had_it
# Sometimes       1221
# Rarely           861
# Never            724
# Almost never     675
# Often            612
# Very Often       325
# Always           176
# Name: count, dtype: int64
#
# - Information about: WELLNESS_maslach_burnout_emotionally_exhausted --
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: Indicate how frequently the following statements apply to you - I feel emotionally exhausted because of my work
# ----------------------------------------------------------------------
#
# Number of NA: 10832
# WELLNESS_maslach_burnout_emotionally_exhausted
# Never                         172
# A few times a year or less    105
# Once a month or less           87
# A few times a month            85
# A few times a week             57
# Every day                      48
# Once a week                    45
# Name: count, dtype: int64
#
# -------- Information about: WELLNESS_maslach_burnout_worn_out --------
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: Indicate how frequently the following statements apply to you - I feel worn out at the end of a working day
# ----------------------------------------------------------------------
#
# Number of NA: 10842
# WELLNESS_maslach_burnout_worn_out
# Never                         124
# A few times a week             94
# A few times a month            91
# A few times a year or less     82
# Every day                      79
# Once a month or less           68
# Once a week                    51
# Name: count, dtype: int64
#
# --------- Information about: WELLNESS_maslach_burnout_tired ----------
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: Indicate how frequently the following statements apply to you - I feel tired as soon as I get up in the morning and see a new working day stretched out in front of me
# ----------------------------------------------------------------------
#
# Number of NA: 10839
# WELLNESS_maslach_burnout_tired
# Never                         142
# Once a month or less           97
# A few times a year or less     93
# Every day                      75
# A few times a month            72
# A few times a week             67
# Once a week                    46
# Name: count, dtype: int64
#
# ------- Information about: WELLNESS_maslach_burnout_understand -------
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: Indicate how frequently the following statements apply to you - I can easily understand the actions of my colleagues/supervisors
# ----------------------------------------------------------------------
#
# Number of NA: 10861
# WELLNESS_maslach_burnout_understand
# Every day                     146
# A few times a month           101
# A few times a week             99
# Never                          93
# Once a month or less           55
# Once a week                    41
# A few times a year or less     35
# Name: count, dtype: int64
#
# -------- Information about: WELLNESS_maslach_burnout_objects ---------
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: Indicate how frequently the following statements apply to you - I get the feeling that I treat some clients/colleagues impersonally, as if they were objects
# ----------------------------------------------------------------------
#
# Number of NA: 10863
# WELLNESS_maslach_burnout_objects
# Never                         302
# A few times a month            78
# Once a month or less           60
# A few times a year or less     44
# Once a week                    37
# A few times a week             33
# Every day                      14
# Name: count, dtype: int64
#
# -- Information about: WELLNESS_maslach_burnout_working_with_people ---
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: Indicate how frequently the following statements apply to you - Working with people the whole day is stressful for me
# ----------------------------------------------------------------------
#
# Number of NA: 10862
# WELLNESS_maslach_burnout_working_with_people
# Never                         160
# Once a month or less           93
# A few times a year or less     81
# A few times a month            71
# Every day                      67
# A few times a week             52
# Once a week                    45
# Name: count, dtype: int64
#
# ----- Information about: WELLNESS_maslach_burnout_deal_problems ------
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: Indicate how frequently the following statements apply to you - I deal with other peoples problems successfully
# ----------------------------------------------------------------------
#
# Number of NA: 10862
# WELLNESS_maslach_burnout_deal_problems
# A few times a week            138
# Once a month or less           95
# Every day                      86
# A few times a month            77
# A few times a year or less     64
# Once a week                    57
# Never                          52
# Name: count, dtype: int64
#
# ------- Information about: WELLNESS_maslach_burnout_burned_out -------
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: Indicate how frequently the following statements apply to you - I feel burned out because of my work
# ----------------------------------------------------------------------
#
# Number of NA: 10867
# WELLNESS_maslach_burnout_burned_out
# Never                         152
# A few times a year or less    116
# Once a month or less           84
# A few times a month            60
# Every day                      58
# A few times a week             51
# Once a week                    43
# Name: count, dtype: int64
#
# ------- Information about: WELLNESS_maslach_burnout_influence --------
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: Indicate how frequently the following statements apply to you - I feel that I influence other people positively through my work
# ----------------------------------------------------------------------
#
# Number of NA: 10867
# WELLNESS_maslach_burnout_influence
# A few times a week            105
# Every day                     100
# Never                          87
# A few times a month            84
# Once a month or less           74
# Once a week                    61
# A few times a year or less     53
# Name: count, dtype: int64
#
# -------- Information about: WELLNESS_maslach_burnout_callous ---------
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: Indicate how frequently the following statements apply to you - I have become more callous to people since I have started doing this job
# ----------------------------------------------------------------------
#
# Number of NA: 10872
# WELLNESS_maslach_burnout_callous
# Never                         284
# A few times a month            83
# A few times a year or less     61
# Once a month or less           49
# A few times a week             32
# Every day                      25
# Once a week                    25
# Name: count, dtype: int64
#
# --- Information about: WELLNESS_maslach_burnout_emotionally_harder ---
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: Indicate how frequently the following statements apply to you - Im afraid that my work makes me emotionally harder
# ----------------------------------------------------------------------
#
# Number of NA: 10874
# WELLNESS_maslach_burnout_emotionally_harder
# Never                         260
# A few times a year or less     69
# Once a week                    62
# A few times a month            61
# Once a month or less           44
# A few times a week             31
# Every day                      30
# Name: count, dtype: int64
#
# ----- Information about: WELLNESS_maslach_burnout_full_of_energy -----
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: Indicate how frequently the following statements apply to you - I feel full of energy
# ----------------------------------------------------------------------
#
# Number of NA: 10861
# WELLNESS_maslach_burnout_full_of_energy
# A few times a week            140
# Once a month or less           95
# Never                          92
# A few times a month            73
# Once a week                    64
# A few times a year or less     59
# Every day                      47
# Name: count, dtype: int64
#
# ------- Information about: WELLNESS_maslach_burnout_frustrated -------
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: Indicate how frequently the following statements apply to you - I feel frustrated by my work
# ----------------------------------------------------------------------
#
# Number of NA: 10872
# WELLNESS_maslach_burnout_frustrated
# Never                         130
# A few times a month           113
# A few times a year or less     87
# A few times a week             69
# Once a month or less           65
# Once a week                    53
# Every day                      42
# Name: count, dtype: int64
#
# -------- Information about: WELLNESS_maslach_burnout_too_hard --------
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: Indicate how frequently the following statements apply to you - I get the feeling that I work too hard
# ----------------------------------------------------------------------
#
# Number of NA: 10872
# WELLNESS_maslach_burnout_too_hard
# Never                         136
# A few times a month           102
# A few times a year or less     77
# Once a month or less           75
# Every day                      64
# A few times a week             60
# Once a week                    45
# Name: count, dtype: int64
#
# ----- Information about: WELLNESS_maslach_burnout_not_interested -----
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: Indicate how frequently the following statements apply to you - Im not really interested in what is going on with many of my colleagues
# ----------------------------------------------------------------------
#
# Number of NA: 10875
# WELLNESS_maslach_burnout_not_interested
# Never                         159
# Once a month or less          107
# A few times a month            76
# A few times a year or less     67
# A few times a week             63
# Every day                      55
# Once a week                    29
# Name: count, dtype: int64
#
# ----- Information about: WELLNESS_maslach_burnout_direct_contact -----
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: Indicate how frequently the following statements apply to you - Being in direct contact with people at work is too stressful
# ----------------------------------------------------------------------
#
# Number of NA: 10873
# WELLNESS_maslach_burnout_direct_contact
# Never                         180
# Once a month or less           87
# A few times a year or less     75
# A few times a month            66
# A few times a week             54
# Once a week                    52
# Every day                      44
# Name: count, dtype: int64
#
# -------- Information about: WELLNESS_maslach_burnout_relaxed ---------
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: Indicate how frequently the following statements apply to you - I find it easy to build a relaxed atmosphere in my working environment
# ----------------------------------------------------------------------
#
# Number of NA: 10876
# WELLNESS_maslach_burnout_relaxed
# Never                         115
# A few times a month            96
# A few times a week             93
# Every day                      90
# Once a week                    61
# Once a month or less           55
# A few times a year or less     45
# Name: count, dtype: int64
#
# ------- Information about: WELLNESS_maslach_burnout_stimulated -------
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: Indicate how frequently the following statements apply to you - I feel stimulated when I been working closely with my colleagues
# ----------------------------------------------------------------------
#
# Number of NA: 10874
# WELLNESS_maslach_burnout_stimulated
# Never                         118
# Once a month or less          103
# A few times a week             90
# A few times a month            72
# Every day                      61
# Once a week                    57
# A few times a year or less     56
# Name: count, dtype: int64
#
# ------- Information about: WELLNESS_maslach_burnout_rewarding --------
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: Indicate how frequently the following statements apply to you - I have achieved many rewarding objectives in my work
# ----------------------------------------------------------------------
#
# Number of NA: 10875
# WELLNESS_maslach_burnout_rewarding
# A few times a month           111
# Never                         100
# A few times a week             89
# A few times a year or less     80
# Once a month or less           66
# Every day                      65
# Once a week                    45
# Name: count, dtype: int64
#
# -------- Information about: WELLNESS_maslach_burnout_wits_end --------
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: Indicate how frequently the following statements apply to you - I feel as if Im at my wits end
# ----------------------------------------------------------------------
#
# Number of NA: 10871
# WELLNESS_maslach_burnout_wits_end
# Never                         168
# A few times a month            96
# A few times a year or less     95
# Once a month or less           67
# A few times a week             51
# Every day                      43
# Once a week                    40
# Name: count, dtype: int64
#
# ------ Information about: WELLNESS_maslach_burnout_very_relaxed ------
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: Indicate how frequently the following statements apply to you - In my work I am very relaxed when dealing with emotional problems
# ----------------------------------------------------------------------
#
# Number of NA: 10883
# WELLNESS_maslach_burnout_very_relaxed
# A few times a year or less    106
# Never                         101
# A few times a week             93
# Once a month or less           70
# A few times a month            66
# Every day                      60
# Once a week                    52
# Name: count, dtype: int64
#
# --------- Information about: WELLNESS_maslach_burnout_blame ----------
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: Indicate how frequently the following statements apply to you - I have the feeling that my colleagues blame me for some of their problems
# ----------------------------------------------------------------------
#
# Number of NA: 10876
# WELLNESS_maslach_burnout_blame
# Never                         255
# Once a month or less           81
# A few times a year or less     79
# A few times a month            45
# Once a week                    39
# A few times a week             31
# Every day                      25
# Name: count, dtype: int64
#
# ------------- Information about: WELLNESS_burnout_direct -------------
# ------------------------ Dataset: 2022_cross -------------------------
# --- Question: Thinking about your work, do you feel œburned out? ----
# ----------------------------------------------------------------------
#
# Number of NA: 10833
# WELLNESS_burnout_direct
# No     354
# Yes    244
# Name: count, dtype: int64
#
# --- Information about: WELLNESS_malach_pines_burnout_measure_score ---
# -------------------- No associated question found --------------------
# Number of NA: 6966
# WELLNESS_malach_pines_burnout_measure_score
# 4.0    207
# 3.9    182
# 3.5    173
# 3.8    165
# 3.6    164
#       ...
# 6.5      7
# 6.6      6
# 6.9      5
# 6.7      3
# 6.8      3
# Name: count, Length: 61, dtype: int64
#
# - Information about: WELLNESS_malach_pines_burnout_measure_score_y_n -
# -------------------- No associated question found --------------------
# Number of NA: 6966
# WELLNESS_malach_pines_burnout_measure_score_y_n
# No (1-3)     3033
# Yes (4-7)    1432
# Name: count, dtype: int64
#
#  Information about: WELLNESS_maslach_burnout_exhaustion_subscale_score
# -------------------- No associated question found --------------------
# Number of NA: 10899
# WELLNESS_maslach_burnout_exhaustion_subscale_score
# 0.0     36
# 23.0    36
# 27.0    22
# 10.0    20
# 9.0     18
# 26.0    15
# 16.0    15
# 15.0    14
# 24.0    14
# 25.0    13
# 22.0    13
# 34.0    13
# 5.0     12
# 11.0    12
# 29.0    12
# 18.0    12
# 28.0    12
# 30.0    12
# 8.0     12
# 17.0    11
# 6.0     10
# 38.0    10
# 20.0    10
# 32.0    10
# 14.0    10
# 12.0    10
# 19.0     9
# 2.0      9
# 31.0     9
# 21.0     9
# 1.0      9
# 45.0     7
# 4.0      7
# 36.0     7
# 7.0      7
# 37.0     6
# 53.0     6
# 13.0     5
# 3.0      5
# 54.0     5
# 44.0     5
# 33.0     5
# 35.0     4
# 41.0     4
# 39.0     4
# 46.0     4
# 42.0     4
# 43.0     4
# 51.0     4
# 47.0     3
# 49.0     2
# 52.0     2
# 50.0     1
# 40.0     1
# 48.0     1
# Name: count, dtype: int64
#
#  Information about: WELLNESS_maslach_burnout_depersonalization_subscale_score
# -------------------- No associated question found --------------------
# Number of NA: 10891
# WELLNESS_maslach_burnout_depersonalization_subscale_score
# 0.0     92
# 14.0    43
# 6.0     37
# 12.0    32
# 1.0     31
# 2.0     28
# 5.0     27
# 3.0     26
# 4.0     24
# 7.0     23
# 15.0    20
# 13.0    17
# 16.0    16
# 10.0    15
# 17.0    14
# 11.0    14
# 9.0     13
# 8.0     13
# 18.0    13
# 19.0    10
# 22.0     7
# 21.0     6
# 23.0     6
# 20.0     5
# 24.0     2
# 29.0     2
# 26.0     2
# 28.0     1
# 27.0     1
# Name: count, dtype: int64
#
#  Information about: WELLNESS_maslach_burnout_accomplishment_subscale_score
# -------------------- No associated question found --------------------
# Number of NA: 10906
# WELLNESS_maslach_burnout_accomplishment_subscale_score
# 30.0    39
# 24.0    23
# 21.0    20
# 16.0    19
# 20.0    19
# 22.0    18
# 48.0    18
# 18.0    18
# 26.0    17
# 23.0    17
# 28.0    17
# 32.0    17
# 15.0    15
# 29.0    15
# 13.0    14
# 14.0    14
# 33.0    13
# 19.0    12
# 8.0     11
# 42.0    11
# 25.0    11
# 27.0    10
# 12.0    10
# 7.0     10
# 38.0     9
# 43.0     9
# 11.0     9
# 10.0     9
# 31.0     8
# 35.0     8
# 6.0      8
# 40.0     7
# 9.0      7
# 5.0      7
# 2.0      6
# 36.0     6
# 17.0     6
# 39.0     5
# 34.0     5
# 0.0      4
# 3.0      4
# 37.0     4
# 4.0      3
# 47.0     3
# 45.0     3
# 1.0      2
# 44.0     2
# 41.0     2
# 46.0     1
# Name: count, dtype: int64
#
#  Information about: WELLNESS_maslach_burnout_exhaustion_subscale_score_y_n
# -------------------- No associated question found --------------------
# Number of NA: 10899
# WELLNESS_maslach_burnout_exhaustion_subscale_score_y_n
# Low Degree (0 - 17)          222
# Moderate Degree (18 - 29)    177
# High Degree (30 - 54)        133
# Name: count, dtype: int64
#
#  Information about: WELLNESS_maslach_burnout_depersonalization_subscale_score_y_n
# -------------------- No associated question found --------------------
# Number of NA: 10891
# WELLNESS_maslach_burnout_depersonalization_subscale_score_y_n
# Low Degree (0 - 5)          228
# High Degree (12 - 29)       197
# Moderate Degree (6 - 11)    115
# Name: count, dtype: int64
#
#  Information about: WELLNESS_maslach_burnout_accomplishment_subscale_score_y_n
# -------------------- No associated question found --------------------
# Number of NA: 10906
# WELLNESS_maslach_burnout_accomplishment_subscale_score_y_n
# Low Degree (0 - 33)          432
# High Degree (40-48)           56
# Moderate Degree (34 - 39)     37
# Name: count, dtype: int64

# %%
data_use.WELLNESS_maslach_burnout_burned_out.value_counts()
# Out:
# WELLNESS_maslach_burnout_burned_out
# Never                         138
# A few times a year or less    106
# Once a month or less           72
# Every day                      52
# A few times a month            51
# A few times a week             45
# Once a week                    40
# Name: count, dtype: int64

# %%
words = ["loneliness"]
to_examine = get_matching_keywords(words)

for col in to_examine:
    get_column_info(col)
# Out:
# --- Information about: LONELY_ucla_loneliness_scale_companionship ----
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: Indicate how often each of the statements below is descriptive of you. - How often do you feel that you lack companionship?
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: Indicate how often each of the statements below is descriptive of you. - How often do you feel that you lack companionship?
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Indicate how often each of the statements below is descriptive of you. - How often do you feel that you lack companionship?
# ----------------------------------------------------------------------
#
# Number of NA: 7531
# LONELY_ucla_loneliness_scale_companionship
# Some of the time    1962
# Hardly Ever         1263
# Often                675
# Name: count, dtype: int64
#
# ------ Information about: LONELY_ucla_loneliness_scale_left_out ------
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: Indicate how often each of the statements below is descriptive of you. - How often do you feel left out?
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: Indicate how often each of the statements below is descriptive of you. - How often do you feel left out?
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Indicate how often each of the statements below is descriptive of you. - How often do you feel left out?
# ----------------------------------------------------------------------
#
# Number of NA: 7535
# LONELY_ucla_loneliness_scale_left_out
# Some of the time    1731
# Hardly Ever         1456
# Often                709
# Name: count, dtype: int64
#
# ------ Information about: LONELY_ucla_loneliness_scale_isolated ------
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: Indicate how often each of the statements below is descriptive of you. - How often do you feel isolated from others?
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: Indicate how often each of the statements below is descriptive of you. - How often do you feel isolated from others?
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Indicate how often each of the statements below is descriptive of you. - How often do you feel isolated from others?
# ----------------------------------------------------------------------
#
# Number of NA: 7541
# LONELY_ucla_loneliness_scale_isolated
# Some of the time    1837
# Hardly Ever         1187
# Often                866
# Name: count, dtype: int64
#
#  Information about: LONELY_dejong_emotional_social_loneliness_scale_emptiness
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: Please indicate for each of the statements, the extent to which they apply to your situation, the way you feel now. - I experience a general sense of emptiness
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: Please indicate for each of the statements, the extent to which they apply to your situation, the way you feel now. - I experience a general sense of emptiness
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: For the statements below, please indicate the extent to which they apply to your situation and the way you feel now. - I experience a general sense of emptiness
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Please indicate for each of the statements, the extent to which they apply to your situation, the way you feel now. - I experience a general sense of emptiness
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cross -------------------------
#  Question: For the statements below, please indicate the extent to which they apply to your situation and the way you feel now. - I experience a general sense of emptiness
# ----------------------------------------------------------------------
#
# Number of NA: 2750
# LONELY_dejong_emotional_social_loneliness_scale_emptiness
# No              3389
# More or less    2920
# Yes             2372
# Name: count, dtype: int64
#
#  Information about: LONELY_dejong_emotional_social_loneliness_scale_rely
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: Please indicate for each of the statements, the extent to which they apply to your situation, the way you feel now. - There are plenty of people I can rely on when I have problems
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: Please indicate for each of the statements, the extent to which they apply to your situation, the way you feel now. - There are plenty of people I can rely on when I have problems
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: For the statements below, please indicate the extent to which they apply to your situation and the way you feel now. - There are plenty of people I can rely on when I have problems
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Please indicate for each of the statements, the extent to which they apply to your situation, the way you feel now. - There are plenty of people I can rely on when I have problems
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cross -------------------------
#  Question: For the statements below, please indicate the extent to which they apply to your situation and the way you feel now. - There are plenty of people I can rely on when I have problems
# ----------------------------------------------------------------------
#
# Number of NA: 2718
# LONELY_dejong_emotional_social_loneliness_scale_rely
# More or less    3435
# Yes             3212
# No              2066
# Name: count, dtype: int64
#
#  Information about: LONELY_dejong_emotional_social_loneliness_scale_trust
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: Please indicate for each of the statements, the extent to which they apply to your situation, the way you feel now. - There are many people I can trust completely
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: Please indicate for each of the statements, the extent to which they apply to your situation, the way you feel now. - There are many people I can trust completely
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: For the statements below, please indicate the extent to which they apply to your situation and the way you feel now. - There are many people I can trust completely
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Please indicate for each of the statements, the extent to which they apply to your situation, the way you feel now. - There are many people I can trust completely
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cross -------------------------
#  Question: For the statements below, please indicate the extent to which they apply to your situation and the way you feel now. - There are many people I can trust completely
# ----------------------------------------------------------------------
#
# Number of NA: 2739
# LONELY_dejong_emotional_social_loneliness_scale_trust
# More or less    3116
# Yes             2905
# No              2671
# Name: count, dtype: int64
#
#  Information about: LONELY_dejong_emotional_social_loneliness_scale_close
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: Please indicate for each of the statements, the extent to which they apply to your situation, the way you feel now. - There are enough people I feel close to
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: Please indicate for each of the statements, the extent to which they apply to your situation, the way you feel now. - There are enough people I feel close to
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: For the statements below, please indicate the extent to which they apply to your situation and the way you feel now. - There are enough people I feel close to
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Please indicate for each of the statements, the extent to which they apply to your situation, the way you feel now. - There are enough people I feel close to
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cross -------------------------
#  Question: For the statements below, please indicate the extent to which they apply to your situation and the way you feel now. - There are enough people I feel close to
# ----------------------------------------------------------------------
#
# Number of NA: 2739
# LONELY_dejong_emotional_social_loneliness_scale_close
# Yes             3594
# More or less    3071
# No              2027
# Name: count, dtype: int64
#
#  Information about: LONELY_dejong_emotional_social_loneliness_scale_miss
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: Please indicate for each of the statements, the extent to which they apply to your situation, the way you feel now. - I miss having people around
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: Please indicate for each of the statements, the extent to which they apply to your situation, the way you feel now. - I miss having people around
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: For the statements below, please indicate the extent to which they apply to your situation and the way you feel now. - I miss having people around
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Please indicate for each of the statements, the extent to which they apply to your situation, the way you feel now. - I miss having people around
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cross -------------------------
#  Question: For the statements below, please indicate the extent to which they apply to your situation and the way you feel now. - I miss having people around
# ----------------------------------------------------------------------
#
# Number of NA: 2763
# LONELY_dejong_emotional_social_loneliness_scale_miss
# Yes             3678
# More or less    2906
# No              2084
# Name: count, dtype: int64
#
#  Information about: LONELY_dejong_emotional_social_loneliness_scale_rejected
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: Please indicate for each of the statements, the extent to which they apply to your situation, the way you feel now. - I often feel rejected
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: Please indicate for each of the statements, the extent to which they apply to your situation, the way you feel now. - I often feel rejected
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: For the statements below, please indicate the extent to which they apply to your situation and the way you feel now. - I often feel rejected
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Please indicate for each of the statements, the extent to which they apply to your situation, the way you feel now. - I often feel rejected
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cross -------------------------
#  Question: For the statements below, please indicate the extent to which they apply to your situation and the way you feel now. - I often feel rejected
# ----------------------------------------------------------------------
#
# Number of NA: 2763
# LONELY_dejong_emotional_social_loneliness_scale_rejected
# No              4141
# More or less    2639
# Yes             1888
# Name: count, dtype: int64
#
# --- Information about: LONELY_existential_loneliness_scale_outlook ---
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: Please use the following scale to rate the extent to which you agree or disagree with each of the following statements IN GENERAL. - I usually feel like people share my outlook on life.
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: Please use the following scale to rate the extent to which you agree or disagree with each of the following statements IN GENERAL. - I usually feel like people share my outlook on life.
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Please use the following scale to rate the extent to which you agree or disagree with each of the following statements IN GENERAL. - I usually feel like people share my outlook on life.
# ----------------------------------------------------------------------
#
# Number of NA: 9286
# LONELY_existential_loneliness_scale_outlook
# 5                        464
# 6                        310
# 4                        308
# 3                        295
# 7                        241
# 2                        179
# 8                        127
# (9) Strongly Disagree    111
# (1) Strongly Agree       110
# Name: count, dtype: int64
#
# -- Information about: LONELY_existential_loneliness_scale_reactions --
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: Please use the following scale to rate the extent to which you agree or disagree with each of the following statements IN GENERAL. - I often have the same reactions to things that other people around me do.
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: Please use the following scale to rate the extent to which you agree or disagree with each of the following statements IN GENERAL. - I often have the same reactions to things that other people around me do.
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Please use the following scale to rate the extent to which you agree or disagree with each of the following statements IN GENERAL. - I often have the same reactions to things that other people around me do.
# ----------------------------------------------------------------------
#
# Number of NA: 9294
# LONELY_existential_loneliness_scale_reactions
# 5                        433
# 6                        344
# 3                        301
# 4                        291
# 7                        285
# 2                        190
# 8                        114
# (9) Strongly Disagree     93
# (1) Strongly Agree        86
# Name: count, dtype: int64
#
# - Information about: LONELY_existential_loneliness_scale_environment -
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: Please use the following scale to rate the extent to which you agree or disagree with each of the following statements IN GENERAL. - People around me tend to react to things in our environment the same way I do.
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: Please use the following scale to rate the extent to which you agree or disagree with each of the following statements IN GENERAL. - People around me tend to react to things in our environment the same way I do.
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Please use the following scale to rate the extent to which you agree or disagree with each of the following statements IN GENERAL. - People around me tend to react to things in our environment the same way I do.
# ----------------------------------------------------------------------
#
# Number of NA: 9293
# LONELY_existential_loneliness_scale_environment
# 5                        446
# 6                        336
# 3                        315
# 4                        312
# 7                        278
# 2                        158
# 8                        112
# (9) Strongly Disagree     94
# (1) Strongly Agree        87
# Name: count, dtype: int64
#
# ---- Information about: LONELY_existential_loneliness_scale_share ----
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: Please use the following scale to rate the extent to which you agree or disagree with each of the following statements IN GENERAL. - People do not often share my perspective.
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: Please use the following scale to rate the extent to which you agree or disagree with each of the following statements IN GENERAL. - People do not often share my perspective.
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Please use the following scale to rate the extent to which you agree or disagree with each of the following statements IN GENERAL. - People do NOT often share my perspective.
# ----------------------------------------------------------------------
#
# Number of NA: 9295
# LONELY_existential_loneliness_scale_share
# 5                        423
# 6                        340
# 7                        330
# 4                        312
# 3                        236
# 8                        172
# 2                        132
# (1) Strongly Agree        97
# (9) Strongly Disagree     94
# Name: count, dtype: int64
#
# - Information about: LONELY_existential_loneliness_scale_understand --
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: Please use the following scale to rate the extent to which you agree or disagree with each of the following statements IN GENERAL. - Other people usually do not understand my experiences.
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: Please use the following scale to rate the extent to which you agree or disagree with each of the following statements IN GENERAL. - Other people usually do not understand my experiences.
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Please use the following scale to rate the extent to which you agree or disagree with each of the following statements IN GENERAL. - Other people usually do NOT understand my experiences.
# ----------------------------------------------------------------------
#
# Number of NA: 9294
# LONELY_existential_loneliness_scale_understand
# 5                        448
# 6                        305
# 7                        303
# 4                        282
# 3                        249
# 8                        165
# 2                        160
# (1) Strongly Agree       125
# (9) Strongly Disagree    100
# Name: count, dtype: int64
#
# -- Information about: LONELY_existential_loneliness_scale_same_take --
# ------------------------ Dataset: 2021_cross -------------------------
#  Question: Please use the following scale to rate the extent to which you agree or disagree with each of the following statements IN GENERAL. - People often have the same œtake or perspective on things that I do.
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2022_cohort ------------------------
#  Question: Please use the following scale to rate the extent to which you agree or disagree with each of the following statements IN GENERAL. - People often have the same œtake or perspective on things that I do.
# ----------------------------------------------------------------------
#
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Please use the following scale to rate the extent to which you agree or disagree with each of the following statements IN GENERAL. - People often have the same œtake or perspective on things that I do.
# ----------------------------------------------------------------------
#
# Number of NA: 9299
# LONELY_existential_loneliness_scale_same_take
# 5                        459
# 6                        349
# 4                        318
# 3                        281
# 7                        269
# 2                        171
# 8                        120
# (1) Strongly Agree        85
# (9) Strongly Disagree     80
# Name: count, dtype: int64
#
# ---------- Information about: LONELINESS_chronic_loneliness ----------
# ------------------------ Dataset: 2022_cross -------------------------
#  Question: Do you continually experience loneliness or social isolation on an ongoing basis?
# ----------------------------------------------------------------------
#
# Number of NA: 10842
# LONELINESS_chronic_loneliness
# No     337
# Yes    252
# Name: count, dtype: int64
#
# ------- Information about: QUALITATIVE_situational_loneliness --------
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: In 2-3 sentences, please tell us in what kinds of situations you feel lonely. How long does the loneliness last? What do you do to feel differently?
# ----------------------------------------------------------------------
#
# Number of NA: 11105
# QUALITATIVE_situational_loneliness
# I don’t feel lonely…I like my own company                                                                                                                                                                     1
# I usually feel lonely when I haven't talked to or hung out with anyone all day. I try to pay attention to how I'm feeling and then reach out to someone to talk or make plans, which makes me feel better.    1
# I rarely feel lonely, usually if I’m by myself in a crowd which will last while I’m in the situation.  To feel differently, I will remove myself.                                                             1
# Rarely do I ever feel lonely. Only when I think of lived one's who have died.                                                                                                                                 1
# on weekends when I don't have any plans, lasts hours, take dog for a walk                                                                                                                                     1
#                                                                                                                                                                                                              ..
# When I'm home alone all day because my husband is working, and everyone else is doing their own thing. It lasts until I find company either via a phone call or text messaging back and forth.                1
# I only feel lonely if my husband is away, but I usually talk to people on the phone or visit someone, or just enjoy reading and music                                                                         1
# When I am unable to go somewhere to take in an event, or when I want to visit my kids or support their activities and be part of their life.  Maybe not so much lonely as frustrated...                       1
# My  illness has made me unable to participate in many activities and can leave me feeling lonely when others are out enjoying themselves.                                                                     1
# I feel lonely when my kids are with their dad or their friends. It lasts until they return or I preoccupy myself. To feel differently I might call your boyfriend or one of my sisters.                       1
# Name: count, Length: 326, dtype: int64
#
#  Information about: ORIGINAL_reactions_to_loneliness_wanted_to_reach_out
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Thinking about the last time you felt lonely, to what extent did the statements below apply to you? - I wanted to reach out to others.
# ----------------------------------------------------------------------
#
# Number of NA: 11085
# ORIGINAL_reactions_to_loneliness_wanted_to_reach_out
# Somewhat             101
# A little              89
# Quite a bit           73
# Not at all            54
# To a great extent     29
# Name: count, dtype: int64
#
#  Information about: ORIGINAL_reactions_to_loneliness_wanted_others_to_reach_out
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Thinking about the last time you felt lonely, to what extent did the statements below apply to you? - I wanted others to reach out to me.
# ----------------------------------------------------------------------
#
# Number of NA: 11087
# ORIGINAL_reactions_to_loneliness_wanted_others_to_reach_out
# Quite a bit          103
# Somewhat              79
# A little              66
# To a great extent     49
# Not at all            47
# Name: count, dtype: int64
#
# - Information about: ORIGINAL_reactions_to_loneliness_did_reach_out --
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Thinking about the last time you felt lonely, to what extent did the statements below apply to you? - I reached out to others.
# ----------------------------------------------------------------------
#
# Number of NA: 11086
# ORIGINAL_reactions_to_loneliness_did_reach_out
# Not at all           99
# Somewhat             85
# A little             75
# Quite a bit          58
# To a great extent    28
# Name: count, dtype: int64
#
#  Information about: ORIGINAL_reactions_to_loneliness_did_not_reach_out
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Thinking about the last time you felt lonely, to what extent did the statements below apply to you? - I did NOT reach out to others.
# ----------------------------------------------------------------------
#
# Number of NA: 11088
# ORIGINAL_reactions_to_loneliness_did_not_reach_out
# Not at all           134
# A little              67
# To a great extent     59
# Somewhat              42
# Quite a bit           41
# Name: count, dtype: int64
#
#  Information about: ORIGINAL_reactions_to_loneliness_wanted_to_be_alone
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Thinking about the last time you felt lonely, to what extent did the statements below apply to you? - I wanted to be alone.
# ----------------------------------------------------------------------
#
# Number of NA: 11085
# ORIGINAL_reactions_to_loneliness_wanted_to_be_alone
# A little             100
# Not at all            98
# Somewhat              98
# Quite a bit           33
# To a great extent     17
# Name: count, dtype: int64
#
#  Information about: ORIGINAL_reactions_to_loneliness_felt_sensitive_to_criticism
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Thinking about the last time you felt lonely, to what extent did the statements below apply to you? - I felt more sensitive to criticism.
# ----------------------------------------------------------------------
#
# Number of NA: 11087
# ORIGINAL_reactions_to_loneliness_felt_sensitive_to_criticism
# Not at all           96
# Somewhat             77
# A little             72
# Quite a bit          70
# To a great extent    29
# Name: count, dtype: int64
#
#  Information about: ORIGINAL_reactions_to_loneliness_felt_people_didnt_like_me
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Thinking about the last time you felt lonely, to what extent did the statements below apply to you? - I felt like people didn't like me.
# ----------------------------------------------------------------------
#
# Number of NA: 11085
# ORIGINAL_reactions_to_loneliness_felt_people_didnt_like_me
# Not at all           181
# Somewhat              54
# A little              50
# Quite a bit           36
# To a great extent     25
# Name: count, dtype: int64
#
#  Information about: ORIGINAL_reactions_to_loneliness_felt_disconnected
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Thinking about the last time you felt lonely, to what extent did the statements below apply to you? - I couldn't stop thinking about how disconnected I was.
# ----------------------------------------------------------------------
#
# Number of NA: 11085
# ORIGINAL_reactions_to_loneliness_felt_disconnected
# Not at all           140
# A little              79
# Somewhat              60
# Quite a bit           45
# To a great extent     22
# Name: count, dtype: int64
#
#  Information about: ORIGINAL_reactions_to_loneliness_worried_people_dont_like_me
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Thinking about the last time you felt lonely, to what extent did the statements below apply to you? - I worried that people don't like me.
# ----------------------------------------------------------------------
#
# Number of NA: 11085
# ORIGINAL_reactions_to_loneliness_worried_people_dont_like_me
# Not at all           181
# A little              64
# Somewhat              48
# Quite a bit           37
# To a great extent     16
# Name: count, dtype: int64
#
#  Information about: ORIGINAL_reactions_to_loneliness_worried_was_a_burden
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Thinking about the last time you felt lonely, to what extent did the statements below apply to you? - I worried that I was a burden.
# ----------------------------------------------------------------------
#
# Number of NA: 11085
# ORIGINAL_reactions_to_loneliness_worried_was_a_burden
# Not at all           171
# A little              69
# Quite a bit           46
# To a great extent     33
# Somewhat              27
# Name: count, dtype: int64
#
#  Information about: ORIGINAL_reactions_to_loneliness_felt_unlikeable -
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Thinking about the last time you felt lonely, to what extent did the statements below apply to you? - I felt unlikeable.
# ----------------------------------------------------------------------
#
# Number of NA: 11089
# ORIGINAL_reactions_to_loneliness_felt_unlikeable
# Not at all           179
# A little              59
# Somewhat              55
# Quite a bit           28
# To a great extent     21
# Name: count, dtype: int64
#
#  Information about: ORIGINAL_reactions_to_loneliness_felt_others_were_excluding_me
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Thinking about the last time you felt lonely, to what extent did the statements below apply to you? - I felt like others were exlcuding me.
# ----------------------------------------------------------------------
#
# Number of NA: 11087
# ORIGINAL_reactions_to_loneliness_felt_others_were_excluding_me
# Not at all           193
# A little              61
# Somewhat              47
# Quite a bit           25
# To a great extent     18
# Name: count, dtype: int64
#
#  Information about: ORIGINAL_reactions_to_loneliness_thought_about_others_feelings
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Thinking about the last time you felt lonely, to what extent did the statements below apply to you? - I thought about others and how they feel.
# ----------------------------------------------------------------------
#
# Number of NA: 11086
# ORIGINAL_reactions_to_loneliness_thought_about_others_feelings
# Somewhat             100
# A little              75
# Not at all            74
# Quite a bit           70
# To a great extent     26
# Name: count, dtype: int64
#
#  Information about: ORIGINAL_reactions_to_loneliness_felt_others_better_off_without_me
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Thinking about the last time you felt lonely, to what extent did the statements below apply to you? - I felt like others in my life would be better off without me.
# ----------------------------------------------------------------------
#
# Number of NA: 11085
# ORIGINAL_reactions_to_loneliness_felt_others_better_off_without_me
# Not at all           227
# A little              54
# Somewhat              30
# To a great extent     20
# Quite a bit           15
# Name: count, dtype: int64
#
# --- Information about: ORIGINAL_reactions_to_loneliness_felt_tired ---
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Thinking about the last time you felt lonely, to what extent did the statements below apply to you? - I felt tired.
# ----------------------------------------------------------------------
#
# Number of NA: 11086
# ORIGINAL_reactions_to_loneliness_felt_tired
# A little             75
# To a great extent    71
# Quite a bit          70
# Not at all           66
# Somewhat             63
# Name: count, dtype: int64
#
#  Information about: ORIGINAL_reactions_to_loneliness_felt_needed_to_focus_on_self
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Thinking about the last time you felt lonely, to what extent did the statements below apply to you? - I felt like I had to focus more on myself.
# ----------------------------------------------------------------------
#
# Number of NA: 11085
# ORIGINAL_reactions_to_loneliness_felt_needed_to_focus_on_self
# Somewhat             112
# Not at all            91
# A little              74
# Quite a bit           47
# To a great extent     22
# Name: count, dtype: int64
#
#  Information about: ORIGINAL_reactions_to_loneliness_felt_needed_to_put_self_first
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Thinking about the last time you felt lonely, to what extent did the statements below apply to you? - I felt I had to put myself first.
# ----------------------------------------------------------------------
#
# Number of NA: 11088
# ORIGINAL_reactions_to_loneliness_felt_needed_to_put_self_first
# Not at all           110
# Somewhat              88
# A little              77
# Quite a bit           47
# To a great extent     21
# Name: count, dtype: int64
#
#  Information about: ORIGINAL_reactions_to_loneliness_wished_was_more_likeable
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Thinking about the last time you felt lonely, to what extent did the statements below apply to you? - I wished I was more likeable.
# ----------------------------------------------------------------------
#
# Number of NA: 11085
# ORIGINAL_reactions_to_loneliness_wished_was_more_likeable
# Not at all           176
# A little              64
# Somewhat              44
# Quite a bit           43
# To a great extent     19
# Name: count, dtype: int64
#
#  Information about: ORIGINAL_reactions_to_loneliness_felt_motivated_to_connect
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Thinking about the last time you felt lonely, to what extent did the statements below apply to you? - I felt motivated to connect.
# ----------------------------------------------------------------------
#
# Number of NA: 11086
# ORIGINAL_reactions_to_loneliness_felt_motivated_to_connect
# A little             104
# Not at all            86
# Somewhat              84
# Quite a bit           53
# To a great extent     18
# Name: count, dtype: int64
#
#  Information about: ORIGINAL_reactions_to_loneliness_worried_about_others_opinions
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Thinking about the last time you felt lonely, to what extent did the statements below apply to you? - I worried about what others think about me.
# ----------------------------------------------------------------------
#
# Number of NA: 11086
# ORIGINAL_reactions_to_loneliness_worried_about_others_opinions
# Not at all           150
# A little              91
# Somewhat              49
# Quite a bit           37
# To a great extent     18
# Name: count, dtype: int64
#
#  Information about: ORIGINAL_reactions_to_loneliness_reflected_on_negative_social_past
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Thinking about the last time you felt lonely, to what extent did the statements below apply to you? - I reflected on negative past social experiences.
# ----------------------------------------------------------------------
#
# Number of NA: 11085
# ORIGINAL_reactions_to_loneliness_reflected_on_negative_social_past
# Not at all           143
# A little              69
# Somewhat              52
# Quite a bit           47
# To a great extent     35
# Name: count, dtype: int64
#
#  Information about: ORIGINAL_reactions_to_loneliness_dwelled_on_past_people_actions
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Thinking about the last time you felt lonely, to what extent did the statements below apply to you? - I dwelled on the actions of people in the past.
# ----------------------------------------------------------------------
#
# Number of NA: 11085
# ORIGINAL_reactions_to_loneliness_dwelled_on_past_people_actions
# Not at all           143
# A little              73
# Somewhat              52
# Quite a bit           44
# To a great extent     34
# Name: count, dtype: int64
#
#  Information about: ORIGINAL_reactions_to_loneliness_wished_was_more_successful
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Thinking about the last time you felt lonely, to what extent did the statements below apply to you? - I wished I was more successful.
# ----------------------------------------------------------------------
#
# Number of NA: 11085
# ORIGINAL_reactions_to_loneliness_wished_was_more_successful
# Not at all           139
# A little              65
# Somewhat              63
# Quite a bit           43
# To a great extent     36
# Name: count, dtype: int64
#
#  Information about: ORIGINAL_reactions_to_loneliness_wished_was_more_attractive
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Thinking about the last time you felt lonely, to what extent did the statements below apply to you? - I wished I was more attractive.
# ----------------------------------------------------------------------
#
# Number of NA: 11086
# ORIGINAL_reactions_to_loneliness_wished_was_more_attractive
# Not at all           148
# Somewhat              60
# A little              58
# Quite a bit           44
# To a great extent     35
# Name: count, dtype: int64
#
#  Information about: ORIGINAL_reactions_to_loneliness_questioned_loneliness_reason
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Thinking about the last time you felt lonely, to what extent did the statements below apply to you? - I questioned why I feel lonely.
# ----------------------------------------------------------------------
#
# Number of NA: 11087
# ORIGINAL_reactions_to_loneliness_questioned_loneliness_reason
# Not at all           118
# A little              98
# Somewhat              65
# Quite a bit           40
# To a great extent     23
# Name: count, dtype: int64
#
# -- Information about: ORIGINAL_reactions_to_loneliness_felt_anxious --
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Thinking about the last time you felt lonely, to what extent did the statements below apply to you? - I felt anxious.
# ----------------------------------------------------------------------
#
# Number of NA: 11086
# ORIGINAL_reactions_to_loneliness_felt_anxious
# Not at all           126
# A little              86
# Somewhat              53
# Quite a bit           49
# To a great extent     31
# Name: count, dtype: int64
#
# - Information about: ORIGINAL_reactions_to_loneliness_felt_stressed --
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Thinking about the last time you felt lonely, to what extent did the statements below apply to you? - I felt stressed.
# ----------------------------------------------------------------------
#
# Number of NA: 11085
# ORIGINAL_reactions_to_loneliness_felt_stressed
# Not at all           105
# A little              97
# Quite a bit           58
# Somewhat              55
# To a great extent     31
# Name: count, dtype: int64
#
# - Information about: ORIGINAL_reactions_to_loneliness_felt_depressed -
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Thinking about the last time you felt lonely, to what extent did the statements below apply to you? - I felt depressed.
# ----------------------------------------------------------------------
#
# Number of NA: 11086
# ORIGINAL_reactions_to_loneliness_felt_depressed
# Not at all           117
# A little              93
# Somewhat              55
# Quite a bit           53
# To a great extent     27
# Name: count, dtype: int64
#
# --- Information about: ORIGINAL_reactions_to_loneliness_felt_angry ---
# ------------------------ Dataset: 2023_cohort ------------------------
#  Question: Thinking about the last time you felt lonely, to what extent did the statements below apply to you? - I felt angry.
# ----------------------------------------------------------------------
#
# Number of NA: 11086
# ORIGINAL_reactions_to_loneliness_felt_angry
# Not at all           186
# A little              88
# Somewhat              38
# Quite a bit           19
# To a great extent     14
# Name: count, dtype: int64
#
# ------- Information about: LONELY_ucla_loneliness_scale_score --------
# -------------------- No associated question found --------------------
# Number of NA: 7552
# LONELY_ucla_loneliness_scale_score
# 6.0    926
# 5.0    803
# 3.0    609
# 4.0    512
# 7.0    422
# 9.0    380
# 8.0    227
# Name: count, dtype: int64
#
# ----- Information about: LONELY_ucla_loneliness_scale_score_y_n ------
# -------------------- No associated question found --------------------
# Number of NA: 7552
# LONELY_ucla_loneliness_scale_score_y_n
# Yes (6-9)    1955
# No (3-5)     1924
# Name: count, dtype: int64
#
#  Information about: LONELY_dejong_emotional_social_loneliness_scale_score
# -------------------- No associated question found --------------------
# Number of NA: 2870
# LONELY_dejong_emotional_social_loneliness_scale_score
# 6.0    1890
# 5.0    1723
# 4.0    1414
# 3.0    1329
# 2.0     971
# 1.0     763
# 0.0     471
# Name: count, dtype: int64
#
#  Information about: LONELY_dejong_emotional_loneliness_sub_scale_score
# -------------------- No associated question found --------------------
# Number of NA: 2820
# LONELY_dejong_emotional_loneliness_sub_scale_score
# 3.0    3457
# 2.0    2018
# 1.0    1866
# 0.0    1270
# Name: count, dtype: int64
#
# - Information about: LONELY_dejong_social_loneliness_sub_scale_score -
# -------------------- No associated question found --------------------
# Number of NA: 2777
# LONELY_dejong_social_loneliness_sub_scale_score
# 3.0    3766
# 2.0    1861
# 0.0    1742
# 1.0    1285
# Name: count, dtype: int64
#
#  Information about: LONELY_dejong_emotional_social_loneliness_scale_score_y_n
# -------------------- No associated question found --------------------
# Number of NA: 2870
# LONELY_dejong_emotional_social_loneliness_scale_score_y_n
# Yes (2-6)    7327
# No (0-1)     1234
# Name: count, dtype: int64
#
#  Information about: LONELY_dejong_emotional_loneliness_sub_scale_score_y_n
# -------------------- No associated question found --------------------
# Number of NA: 2820
# LONELY_dejong_emotional_loneliness_sub_scale_score_y_n
# Yes (1-3)    7341
# No (0)       1270
# Name: count, dtype: int64
#
#  Information about: LONELY_dejong_social_loneliness_sub_scale_score_y_n
# -------------------- No associated question found --------------------
# Number of NA: 2777
# LONELY_dejong_social_loneliness_sub_scale_score_y_n
# Yes (1-3)    6912
# No (0)       1742
# Name: count, dtype: int64
#
#  Information about: LONELY_existential_loneliness_scale_outlook_corrected
# -------------------- No associated question found --------------------
# Number of NA: 9286
# LONELY_existential_loneliness_scale_outlook_corrected
# 5                        464
# 4                        310
# 6                        308
# 7                        295
# 3                        241
# 8                        179
# 2                        127
# (1) Strongly Agree       111
# (9) Strongly Disagree    110
# Name: count, dtype: int64
#
#  Information about: LONELY_existential_loneliness_scale_reactions_corrected
# -------------------- No associated question found --------------------
# Number of NA: 9294
# LONELY_existential_loneliness_scale_reactions_corrected
# 5                        433
# 4                        344
# 7                        301
# 6                        291
# 3                        285
# 8                        190
# 2                        114
# (1) Strongly Agree        93
# (9) Strongly Disagree     86
# Name: count, dtype: int64
#
#  Information about: LONELY_existential_loneliness_scale_environment_corrected
# -------------------- No associated question found --------------------
# Number of NA: 9293
# LONELY_existential_loneliness_scale_environment_corrected
# 5                        446
# 4                        336
# 7                        315
# 6                        312
# 3                        278
# 8                        158
# 2                        112
# (1) Strongly Agree        94
# (9) Strongly Disagree     87
# Name: count, dtype: int64
#
#  Information about: LONELY_existential_loneliness_scale_same_take_corrected
# -------------------- No associated question found --------------------
# Number of NA: 9299
# LONELY_existential_loneliness_scale_same_take_corrected
# 5                        459
# 4                        349
# 6                        318
# 7                        281
# 3                        269
# 8                        171
# 2                        120
# (9) Strongly Disagree     85
# (1) Strongly Agree        80
# Name: count, dtype: int64
#
#  Information about: LONELY_existential_loneliness_scale_share_corrected
# -------------------- No associated question found --------------------
# Number of NA: 9295
# LONELY_existential_loneliness_scale_share_corrected
# 5                        423
# 4                        340
# 3                        330
# 6                        312
# 7                        236
# 2                        172
# 8                        132
# (9) Strongly Disagree     97
# (1) Strongly Agree        94
# Name: count, dtype: int64
#
#  Information about: LONELY_existential_loneliness_scale_understand_corrected
# -------------------- No associated question found --------------------
# Number of NA: 9294
# LONELY_existential_loneliness_scale_understand_corrected
# 5                        448
# 4                        305
# 3                        303
# 6                        282
# 7                        249
# 2                        165
# 8                        160
# (9) Strongly Disagree    125
# (1) Strongly Agree       100
# Name: count, dtype: int64
#
# ---- Information about: LONELY_existential_loneliness_scale_score ----
# -------------------- No associated question found --------------------
# Number of NA: 9326
# LONELY_existential_loneliness_scale_score
# 30.0    170
# 32.0    135
# 31.0    126
# 28.0    124
# 29.0    119
# 33.0    109
# 34.0    106
# 27.0     88
# 24.0     74
# 36.0     72
# 26.0     72
# 23.0     71
# 25.0     70
# 35.0     68
# 38.0     60
# 22.0     55
# 37.0     51
# 18.0     45
# 40.0     37
# 20.0     37
# 21.0     34
# 19.0     31
# 16.0     31
# 17.0     30
# 42.0     28
# 39.0     28
# 14.0     24
# 41.0     21
# 15.0     21
# 45.0     19
# 12.0     16
# 54.0     16
# 13.0     15
# 44.0     14
# 46.0     13
# 43.0     11
# 48.0      8
# 47.0      7
# 11.0      7
# 6.0       6
# 52.0      6
# 10.0      6
# 50.0      5
# 8.0       5
# 49.0      4
# 51.0      4
# 9.0       3
# 7.0       3
# Name: count, dtype: int64

# %%
data_use.LONELY_existential_loneliness_scale_score.value_counts()
# Out:
# LONELY_existential_loneliness_scale_score
# 30.0    136
# 32.0    108
# 28.0     97
# 31.0     94
# 29.0     91
# 34.0     90
# 33.0     83
# 27.0     71
# 36.0     61
# 35.0     58
# 26.0     51
# 25.0     51
# 24.0     50
# 38.0     49
# 23.0     44
# 22.0     42
# 37.0     34
# 40.0     31
# 21.0     29
# 20.0     28
# 39.0     24
# 19.0     24
# 42.0     23
# 18.0     23
# 16.0     22
# 17.0     22
# 45.0     17
# 15.0     16
# 41.0     15
# 14.0     15
# 44.0     13
# 12.0     12
# 54.0     12
# 46.0     10
# 13.0      9
# 43.0      8
# 11.0      7
# 6.0       6
# 48.0      5
# 47.0      4
# 50.0      3
# 52.0      3
# 7.0       3
# 51.0      3
# 49.0      2
# 10.0      2
# 9.0       2
# 8.0       2
# Name: count, dtype: int64
